# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import pandas as pd
import pandas_datareader.data as web
import pickle 
import requests
import tensorflow as tf
import os
# Out:
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
image_path = 'D:/kenneth/agent/images/'
ticker = '^GSPC'
start=('2019-01-01')
end=('2019-12-31')
# df=web.DataReader(ticker,'yahoo',start,end)
# df.to_csv(ticker+'.csv')
df = pd.read_csv('D:/kenneth/agent/'+ticker+'.csv', index_col=0, parse_dates=True)

# %% [markdown]
# #  Agents
#
# * Turtle Trading agent
# * Moving Average agent
# * Signal Rolling agent
# * Policy Gradient agent
# * Q-learning agent
# * Evolution Strategy agent
# * Double Q-learning agent
# * Recurrent Q-learning agent
# * Double Recurrent Q-learning agent
# * Duel Q-learning agent
# * Double Duel Q-learning agent
# * Duel Recurrent Q-learning agent
# * Double Duel Recurrent Q-learning agent
# * Actor-critic agent
# * Actor-critic Duel agent
# * Actor-critic Recurrent agent
# * Actor-critic Duel Recurrent agent
# * Curiosity Q-learning agent
# * Recurrent Curiosity Q-learning agent
# * Duel Curiosity Q-learning agent
# * Neuro-evolution agent
# * Neuro-evolution with Novelty search agent
# * ABCD strategy agent
# * Deep Evolution Strategy

# %% [markdown]
# ## Actor-critic Recurrent agent

# %%
from collections import deque
import random

name = 'Actor-critic Duel Recurrent agent'

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * size_layer))
            cell = tf.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X, cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,
                                                        tf.reduce_mean(feed_action,axis=1,keep_dims=True))

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * size_layer))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            cell = tf.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X, cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            feed_critic = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            feed_critic = tf.nn.relu(feed_critic) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states,
                                                       self.actor.hidden_layer: init_values})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states,
                                                                     self.actor_target.hidden_layer: init_values})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q,
                                                          self.critic.hidden_layer: init_values})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads,
                                                self.actor.hidden_layer: init_values})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target,
                                                 self.critic_target.hidden_layer: init_values})
        for i in range(len(replay)):
            if not replay[0][-2]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards,
                                          self.critic.hidden_layer: init_values})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            
            if np.random.rand() < self.EPSILON:
                action = np.random.randint(self.OUTPUT_SIZE)
            else:
                action, last_state = self.sess.run([self.actor.logits,
                                                  self.actor.last_state],
                                                  feed_dict={self.actor.X:[self.INITIAL_FEATURES],
                                                             self.actor.hidden_layer:init_value})
                action, init_value = np.argmax(action[0]), last_state
                    
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                    
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.actor.logits,
                                                  self.actor.last_state],
                                                  feed_dict={self.actor.X:[self.INITIAL_FEATURES],
                                                             self.actor.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                self.INITIAL_FEATURES = new_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 20, checkpoint = 1, initial_money = initial_money)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000266EDFC38D0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From <ipython-input-3-2cac0f18e22a>:19: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000266EE438F28>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000266EE4A24A8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000266EE572F98>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# epoch: 1, total rewards: 627.581055.3, cost: 0.063754, total money: 10627.581055
# epoch: 2, total rewards: 905.709229.3, cost: 0.096440, total money: 10905.709229
# epoch: 3, total rewards: 98.320801.3, cost: 0.189071, total money: 1085.560791
# epoch: 4, total rewards: 63.710205.3, cost: 0.115101, total money: 1143.700439
# epoch: 5, total rewards: 510.690430.3, cost: 0.139825, total money: 4506.020508
# epoch: 6, total rewards: 362.569580.3, cost: 0.525142, total money: 4426.149658
# epoch: 7, total rewards: 1032.670166.3, cost: 0.115193, total money: 8034.720215
# epoch: 8, total rewards: 669.041260.3, cost: 0.174882, total money: 4652.031250
# epoch: 9, total rewards: 1017.330078.3, cost: 0.352284, total money: 8007.040039
# epoch: 10, total rewards: 959.679688.3, cost: 0.105678, total money: 4948.439697
# epoch: 11, total rewards: 742.798828.3, cost: 0.753614, total money: 7736.078857
# epoch: 12, total rewards: 797.490234.3, cost: 0.126073, total money: 10797.490234
# epoch: 13, total rewards: 1148.870361.3, cost: 1.250393, total money: 8144.350342
# epoch: 14, total rewards: 696.739746.3, cost: 0.073895, total money: 7730.589844
# epoch: 15, total rewards: 1117.979736.3, cost: 0.066707, total money: 8111.259766
# epoch: 16, total rewards: 546.969727.3, cost: 0.236328, total money: 4544.499756
# epoch: 17, total rewards: 423.910156.3, cost: 0.306836, total money: 10423.910156
# epoch: 18, total rewards: 1091.349609.3, cost: 0.291263, total money: 8081.059570
# epoch: 19, total rewards: 1097.739990.3, cost: 0.113698, total money: 5082.929932
# epoch: 20, total rewards: 301.859375.3, cost: 1.210045, total money: 7291.569336

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 3: buy 1 unit at price 2549.689941, total balance 7450.310059
# day 7: buy 1 unit at price 2596.260010, total balance 4854.050049
# day 9: buy 1 unit at price 2610.300049, total balance 2243.750000
# day 10, sell 1 unit at price 2616.100098, investment 2.604637 %, total balance 4859.850098,
# day 12, sell 1 unit at price 2670.709961, investment 2.867585 %, total balance 7530.560059,
# day 13, sell 1 unit at price 2632.899902, investment 0.865795 %, total balance 10163.459961,
# day 14: buy 1 unit at price 2638.699951, total balance 7524.760010
# day 16: buy 1 unit at price 2664.760010, total balance 4860.000000
# day 17, sell 1 unit at price 2643.850098, investment 0.195177 %, total balance 7503.850098,
# day 18, sell 1 unit at price 2640.000000, investment -0.929165 %, total balance 10143.850098,
# day 20: buy 1 unit at price 2704.100098, total balance 7439.750000
# day 22: buy 1 unit at price 2724.870117, total balance 4714.879883
# day 23: buy 1 unit at price 2737.699951, total balance 1977.179932
# day 24, sell 1 unit at price 2731.610107, investment 1.017344 %, total balance 4708.790039,
# day 25: buy 1 unit at price 2706.050049, total balance 2002.739990
# day 26, sell 1 unit at price 2707.879883, investment -0.623525 %, total balance 4710.619873,
# day 27, sell 1 unit at price 2709.800049, investment -1.019100 %, total balance 7420.419922,
# day 28: buy 1 unit at price 2744.729980, total balance 4675.689941
# day 29, sell 1 unit at price 2753.030029, investment 1.736109 %, total balance 7428.719971,
# day 30: buy 1 unit at price 2745.729980, total balance 4682.989990
# day 31: buy 1 unit at price 2775.600098, total balance 1907.389893
# day 33, sell 1 unit at price 2784.699951, investment 1.456244 %, total balance 4692.089844,
# day 36: buy 1 unit at price 2796.110107, total balance 1895.979736
# day 40, sell 1 unit at price 2803.689941, investment 2.110913 %, total balance 4699.669678,
# day 41, sell 1 unit at price 2792.810059, investment 0.620045 %, total balance 7492.479736,
# day 42, sell 1 unit at price 2789.649902, investment -0.231043 %, total balance 10282.129639,
# day 46: buy 1 unit at price 2783.300049, total balance 7498.829590
# day 47, sell 1 unit at price 2791.520020, investment 0.295332 %, total balance 10290.349609,
# day 52: buy 1 unit at price 2832.570068, total balance 7457.779541
# day 53: buy 1 unit at price 2824.229980, total balance 4633.549561
# day 55: buy 1 unit at price 2800.709961, total balance 1832.839600
# day 57, sell 1 unit at price 2818.459961, investment -0.498138 %, total balance 4651.299561,
# day 59, sell 1 unit at price 2815.439941, investment -0.311237 %, total balance 7466.739502,
# day 60, sell 1 unit at price 2834.399902, investment 1.202907 %, total balance 10301.139404,
# day 62: buy 1 unit at price 2867.239990, total balance 7433.899414
# day 64: buy 1 unit at price 2879.389893, total balance 4554.509521
# day 65, sell 1 unit at price 2892.739990, investment 0.889357 %, total balance 7447.249512,
# day 66, sell 1 unit at price 2895.770020, investment 0.568875 %, total balance 10343.019531,
# day 72: buy 1 unit at price 2907.060059, total balance 7435.959473
# day 73, sell 1 unit at price 2900.449951, investment -0.227381 %, total balance 10336.409424,
# day 85: buy 1 unit at price 2932.469971, total balance 7403.939453
# day 86: buy 1 unit at price 2884.050049, total balance 4519.889404
# day 87: buy 1 unit at price 2879.419922, total balance 1640.469482
# day 89, sell 1 unit at price 2881.399902, investment -1.741538 %, total balance 4521.869385,
# day 90, sell 1 unit at price 2811.870117, investment -2.502728 %, total balance 7333.739502,
# day 92, sell 1 unit at price 2850.959961, investment -0.988392 %, total balance 10184.699463,
# day 98: buy 1 unit at price 2822.239990, total balance 7362.459473
# day 99, sell 1 unit at price 2826.060059, investment 0.135356 %, total balance 10188.519531,
# day 100: buy 1 unit at price 2802.389893, total balance 7386.129639
# day 101: buy 1 unit at price 2783.020020, total balance 4603.109619
# day 102: buy 1 unit at price 2788.860107, total balance 1814.249512
# day 103, sell 1 unit at price 2752.060059, investment -1.795961 %, total balance 4566.309570,
# day 104: buy 1 unit at price 2744.449951, total balance 1821.859619
# day 108, sell 1 unit at price 2873.340088, investment 3.245398 %, total balance 4695.199707,
# day 110: buy 1 unit at price 2885.719971, total balance 1809.479736
# day 113, sell 1 unit at price 2886.979980, investment 3.518279 %, total balance 4696.459717,
# day 118: buy 1 unit at price 2950.459961, total balance 1745.999756
# day 119, sell 1 unit at price 2945.350098, investment 7.320234 %, total balance 4691.349854,
# day 120: buy 1 unit at price 2917.379883, total balance 1773.969971
# day 121, sell 1 unit at price 2913.780029, investment 0.972376 %, total balance 4687.750000,
# day 122, sell 1 unit at price 2924.919922, investment -0.865629 %, total balance 7612.669922,
# day 125, sell 1 unit at price 2973.010010, investment 1.906852 %, total balance 10585.679932,
# day 126: buy 1 unit at price 2995.820068, total balance 7589.859863
# day 127: buy 1 unit at price 2990.409912, total balance 4599.449951
# day 128: buy 1 unit at price 2975.949951, total balance 1623.500000
# day 130, sell 1 unit at price 2993.070068, investment -0.091795 %, total balance 4616.570068,
# day 131: buy 1 unit at price 2999.909912, total balance 1616.660156
# day 133, sell 1 unit at price 3014.300049, investment 0.798892 %, total balance 4630.960205,
# day 134: buy 1 unit at price 3004.040039, total balance 1626.920166
# day 135, sell 1 unit at price 2984.419922, investment 0.284614 %, total balance 4611.340088,
# day 137: buy 1 unit at price 2976.610107, total balance 1634.729980
# day 138, sell 1 unit at price 2985.030029, investment -0.496011 %, total balance 4619.760010,
# day 139: buy 1 unit at price 3005.469971, total balance 1614.290039
# day 142, sell 1 unit at price 3025.860107, investment 0.726357 %, total balance 4640.150146,
# day 143, sell 1 unit at price 3020.969971, investment 1.490281 %, total balance 7661.120117,
# day 144, sell 1 unit at price 3013.179932, investment 0.256531 %, total balance 10674.300049,
# day 146: buy 1 unit at price 2953.560059, total balance 7720.739990
# day 148, sell 1 unit at price 2844.739990, investment -3.684370 %, total balance 10565.479980,
# day 151: buy 1 unit at price 2938.090088, total balance 7627.389893
# day 152, sell 1 unit at price 2918.649902, investment -0.661661 %, total balance 10546.039795,
# day 154: buy 1 unit at price 2926.320068, total balance 7619.719727
# day 155: buy 1 unit at price 2840.600098, total balance 4779.119629
# day 157: buy 1 unit at price 2888.679932, total balance 1890.439697
# day 161, sell 1 unit at price 2922.949951, investment -0.115166 %, total balance 4813.389648,
# day 163: buy 1 unit at price 2878.379883, total balance 1935.009766
# day 164, sell 1 unit at price 2869.159912, investment 1.005415 %, total balance 4804.169678,
# day 166: buy 1 unit at price 2924.580078, total balance 1879.589600
# day 167, sell 1 unit at price 2926.459961, investment 1.307865 %, total balance 4806.049561,
# day 168, sell 1 unit at price 2906.270020, investment 0.968953 %, total balance 7712.319580,
# day 170: buy 1 unit at price 2976.000000, total balance 4736.319580
# day 171, sell 1 unit at price 2978.709961, investment 1.850860 %, total balance 7715.029541,
# day 172, sell 1 unit at price 2978.429932, investment 0.081651 %, total balance 10693.459473,
# day 174: buy 1 unit at price 3000.929932, total balance 7692.529541
# day 177, sell 1 unit at price 2997.959961, investment -0.098968 %, total balance 10690.489502,
# day 182: buy 1 unit at price 2991.780029, total balance 7698.709473
# day 183: buy 1 unit at price 2966.600098, total balance 4732.109375
# day 184: buy 1 unit at price 2984.870117, total balance 1747.239258
# day 189, sell 1 unit at price 2887.610107, investment -3.481871 %, total balance 4634.849365,
# day 190: buy 1 unit at price 2910.629883, total balance 1724.219482
# day 195, sell 1 unit at price 2938.129883, investment -0.959692 %, total balance 4662.349365,
# day 198: buy 1 unit at price 2995.679932, total balance 1666.669434
# day 200, sell 1 unit at price 2997.949951, investment 0.438204 %, total balance 4664.619385,
# day 201, sell 1 unit at price 2986.199951, investment 2.596348 %, total balance 7650.819336,
# day 202, sell 1 unit at price 3006.719971, investment 0.368532 %, total balance 10657.539307,

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
plt.plot(close, color='k', lw=2., alpha=0.5)
plt.plot(close, '^', markersize=10, color='g', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='r', label = 'selling signal', markevery = states_sell)
plt.title(name+'\n'+'daily Trade Recommendations')
plt.legend()
plt.xticks(rotation=45)
plt.gca().axes.get_yaxis().set_visible(False)
fig.tight_layout()
plt.savefig('images/'+ticker+name+'.png', facecolor='yellowgreen', dpi=100)
plt.show()

# %%
display_days = 30
total_days= df.shape[0]
display_from = total_days-display_days

# %%
new_buy = []
for i in(states_buy):
    if i > display_from:
        adj = i- display_from
        new_buy.append(adj)
new_buy
# Out:
# [5, 6, 7, 13, 21]

# %%
new_sell = []
for i in(states_sell):
    if i > display_from:
        adj = i- display_from
        new_sell.append(adj)
new_sell
# Out:
# [12, 18, 23, 24, 25]

# %%
close = df['Close'][-display_days:]
fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
plt.plot(close, color='k', lw=3., alpha=0.5)
plt.plot(close, '^', markersize=12, color='g',alpha=1.0,label = 'buying signal', markevery = new_buy)
plt.plot(close, 'v', markersize=12, color='r',alpha=1.0, label = 'selling signal', markevery = new_sell)
plt.title(name+'\n'+'Last '+str(display_days)+' daily days Trade Recommendations')
plt.legend()
plt.xticks(rotation=45)
plt.gca().axes.get_yaxis().set_visible(False)
fig.tight_layout()
#plt.savefig('images/'+ticker+name+'.png', facecolor='yellowgreen', dpi=100)
plt.show()
