# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import pandas as pd
import pandas_datareader.data as web
import pickle 
import requests
import tensorflow as tf
# Out:
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
image_path = 'D:/kenneth/agent/images/'
ticker = '^GSPC'
start=('2019-01-01')
end=('2019-12-31')
# df=web.DataReader(ticker,'yahoo',start,end)
# df.to_csv(ticker+'.csv')
df = pd.read_csv('D:/kenneth/agent/'+ticker+'.csv', index_col=0, parse_dates=True)

# %% [markdown]
# #  Agents
#
# * Turtle Trading agent
# * Moving Average agent
# * Signal Rolling agent
# * Policy Gradient agent
# * Q-learning agent
# * Evolution Strategy agent
# * Double Q-learning agent
# * Recurrent Q-learning agent
# * Double Recurrent Q-learning agent
# * Duel Q-learning agent
# * Double Duel Q-learning agent
# * Duel Recurrent Q-learning agent
# * Double Duel Recurrent Q-learning agent
# * Actor-critic agent
# * Actor-critic Duel agent
# * Actor-critic Recurrent agent
# * Actor-critic Duel Recurrent agent
# * Curiosity Q-learning agent
# * Recurrent Curiosity Q-learning agent
# * Duel Curiosity Q-learning agent
# * Neuro-evolution agent
# * Neuro-evolution with Novelty search agent
# * ABCD strategy agent
# * Deep Evolution Strategy

# %% [markdown]
# ## Evolution Strategy agent

# %%
import pkg_resources
import types


name = 'Evolution Strategy agent'


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# tensorflow==1.10.0
# seaborn==0.9.0
# requests==2.19.1
# pandas==0.23.4
# numpy==1.17.2
# matplotlib==2.2.3

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
import time
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 10000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: 17.521985
# iter 20. reward: 21.534082
# iter 30. reward: 25.702383
# iter 40. reward: 26.218479
# iter 50. reward: 27.408982
# iter 60. reward: 26.920583
# iter 70. reward: 25.861382
# iter 80. reward: 27.128579
# iter 90. reward: 27.991582
# iter 100. reward: 28.084480
# iter 110. reward: 28.685388
# iter 120. reward: 28.157483
# iter 130. reward: 28.332485
# iter 140. reward: 29.038784
# iter 150. reward: 28.892683
# iter 160. reward: 29.489182
# iter 170. reward: 29.432285
# iter 180. reward: 29.641384
# iter 190. reward: 30.216289
# iter 200. reward: 30.765891
# iter 210. reward: 30.336089
# iter 220. reward: 30.726394
# iter 230. reward: 30.454390
# iter 240. reward: 29.923789
# iter 250. reward: 29.917791
# iter 260. reward: 30.683489
# iter 270. reward: 30.679993
# iter 280. reward: 30.496787
# iter 290. reward: 30.671389
# iter 300. reward: 30.200784
# iter 310. reward: 30.565291
# iter 320. reward: 28.896287
# iter 330. reward: 29.893291
# iter 340. reward: 29.787390
# iter 350. reward: 30.600793
# iter 360. reward: 30.172092
# iter 370. reward: 29.774988
# iter 380. reward: 30.834189
# iter 390. reward: 30.740989
# iter 400. reward: 30.187490
# iter 410. reward: 31.147791
# iter 420. reward: 30.739988
# iter 430. reward: 30.577488
# iter 440. reward: 30.760989
# iter 450. reward: 30.934988
# iter 460. reward: 31.110789
# iter 470. reward: 31.625188
# iter 480. reward: 31.346289
# iter 490. reward: 31.346289
# iter 500. reward: 31.382988
# time taken to train: 202.67431592941284 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 1: buy 1 unit at price 2447.889893, total balance 7552.110107
# day 3: buy 1 unit at price 2549.689941, total balance 5002.420166
# day 4: buy 1 unit at price 2574.409912, total balance 2428.010254
# day 7, sell 1 unit at price 2596.260010, investment 6.061143 %, total balance 5024.270264,
# day 8: buy 1 unit at price 2582.610107, total balance 2441.660156
# day 12, sell 1 unit at price 2670.709961, investment 4.746460 %, total balance 5112.370117,
# day 13: buy 1 unit at price 2632.899902, total balance 2479.470215
# day 14, sell 1 unit at price 2638.699951, investment 2.497273 %, total balance 5118.170166,
# day 15: buy 1 unit at price 2642.330078, total balance 2475.840088
# day 16, sell 1 unit at price 2664.760010, investment 3.180887 %, total balance 5140.600098,
# day 17: buy 1 unit at price 2643.850098, total balance 2496.750000
# day 22, sell 1 unit at price 2724.870117, investment 3.493115 %, total balance 5221.620117,
# day 24, sell 1 unit at price 2731.610107, investment 3.378837 %, total balance 7953.230225,
# day 25: buy 1 unit at price 2706.050049, total balance 5247.180176
# day 27: buy 1 unit at price 2709.800049, total balance 2537.380127
# day 30, sell 1 unit at price 2745.729980, investment 3.853467 %, total balance 5283.110107,
# day 31, sell 1 unit at price 2775.600098, investment 2.570169 %, total balance 8058.710205,
# day 32: buy 1 unit at price 2779.760010, total balance 5278.950195
# day 33, sell 1 unit at price 2784.699951, investment 2.764038 %, total balance 8063.650146,
# day 34: buy 1 unit at price 2774.879883, total balance 5288.770264
# day 37: buy 1 unit at price 2793.899902, total balance 2494.870361
# day 38, sell 1 unit at price 2792.379883, investment 0.453991 %, total balance 5287.250244,
# day 39: buy 1 unit at price 2784.489990, total balance 2502.760254
# day 40, sell 1 unit at price 2803.689941, investment 1.038245 %, total balance 5306.450195,
# day 41, sell 1 unit at price 2792.810059, investment -0.039008 %, total balance 8099.260254,
# day 42, sell 1 unit at price 2789.649902, investment 0.185309 %, total balance 10888.910156,
# day 44: buy 1 unit at price 2748.929932, total balance 8139.980225
# day 45: buy 1 unit at price 2743.070068, total balance 5396.910156
# day 46: buy 1 unit at price 2783.300049, total balance 2613.610107
# day 48, sell 1 unit at price 2810.919922, investment 2.255059 %, total balance 5424.530029,
# day 49, sell 1 unit at price 2808.479980, investment 2.384551 %, total balance 8233.010010,
# day 50, sell 1 unit at price 2822.479980, investment 1.407679 %, total balance 11055.489990,
# day 51: buy 1 unit at price 2832.939941, total balance 8222.550049
# day 54, sell 1 unit at price 2854.879883, investment 0.774458 %, total balance 11077.429932,
# day 55: buy 1 unit at price 2800.709961, total balance 8276.719971
# day 56: buy 1 unit at price 2798.360107, total balance 5478.359863
# day 57, sell 1 unit at price 2818.459961, investment 0.633768 %, total balance 8296.819824,
# day 58: buy 1 unit at price 2805.370117, total balance 5491.449707
# day 59: buy 1 unit at price 2815.439941, total balance 2676.009766
# day 60, sell 1 unit at price 2834.399902, investment 1.287890 %, total balance 5510.409668,
# day 62: buy 1 unit at price 2867.239990, total balance 2643.169678
# day 68, sell 1 unit at price 2888.209961, investment 2.952902 %, total balance 5531.379639,
# day 69: buy 1 unit at price 2888.320068, total balance 2643.059570
# day 71, sell 1 unit at price 2905.580078, investment 3.201636 %, total balance 5548.639648,
# day 74: buy 1 unit at price 2905.030029, total balance 2643.609619
# day 76, sell 1 unit at price 2933.679932, investment 2.317209 %, total balance 5577.289551,
# day 77: buy 1 unit at price 2927.250000, total balance 2650.039551
# day 79, sell 1 unit at price 2939.879883, investment 1.785114 %, total balance 5589.919434,
# day 80, sell 1 unit at price 2943.030029, investment 1.308076 %, total balance 8532.949463,
# day 82, sell 1 unit at price 2923.729980, investment -0.120250 %, total balance 11456.679443,
# day 85: buy 1 unit at price 2932.469971, total balance 8524.209473
# day 86: buy 1 unit at price 2884.050049, total balance 5640.159424
# day 87, sell 1 unit at price 2879.419922, investment -1.809057 %, total balance 8519.579346,
# day 88, sell 1 unit at price 2870.719971, investment -0.462200 %, total balance 11390.299316,
# day 89: buy 1 unit at price 2881.399902, total balance 8508.899414
# day 90: buy 1 unit at price 2811.870117, total balance 5697.029297
# day 92: buy 1 unit at price 2850.959961, total balance 2846.069336
# day 98, sell 1 unit at price 2822.239990, investment -2.053166 %, total balance 5668.309326,
# day 99, sell 1 unit at price 2826.060059, investment 0.504644 %, total balance 8494.369385,
# day 101: buy 1 unit at price 2783.020020, total balance 5711.349365
# day 102: buy 1 unit at price 2788.860107, total balance 2922.489258
# day 103, sell 1 unit at price 2752.060059, investment -3.469004 %, total balance 5674.549316,
# day 104: buy 1 unit at price 2744.449951, total balance 2930.099365
# day 105: buy 1 unit at price 2803.270020, total balance 126.829346
# day 106, sell 1 unit at price 2826.149902, investment 1.549751 %, total balance 2952.979248,
# day 107: buy 1 unit at price 2843.489990, total balance 109.489258
# day 113, sell 1 unit at price 2886.979980, investment 3.518279 %, total balance 2996.469238,
# day 114: buy 1 unit at price 2889.669922, total balance 106.799316
# day 117, sell 1 unit at price 2954.179932, investment 7.641968 %, total balance 3060.979248,
# day 119, sell 1 unit at price 2945.350098, investment 5.068369 %, total balance 6006.329346,
# day 120: buy 1 unit at price 2917.379883, total balance 3088.949463
# day 121: buy 1 unit at price 2913.780029, total balance 175.169434
# day 127, sell 1 unit at price 2990.409912, investment 5.166887 %, total balance 3165.579346,
# day 130: buy 1 unit at price 2993.070068, total balance 172.509277
# day 133, sell 1 unit at price 3014.300049, investment 4.312954 %, total balance 3186.809326,
# day 134, sell 1 unit at price 3004.040039, investment 2.970479 %, total balance 6190.849365,
# day 135, sell 1 unit at price 2984.419922, investment 2.424339 %, total balance 9175.269287,
# day 136, sell 1 unit at price 2995.110107, investment 0.068159 %, total balance 12170.379395,
# day 140: buy 1 unit at price 3019.560059, total balance 9150.819336
# day 141: buy 1 unit at price 3003.669922, total balance 6147.149414
# day 143, sell 1 unit at price 3020.969971, investment 0.046693 %, total balance 9168.119385,
# day 144, sell 1 unit at price 3013.179932, investment 0.316613 %, total balance 12181.299316,
# day 147: buy 1 unit at price 2932.050049, total balance 9249.249268
# day 148: buy 1 unit at price 2844.739990, total balance 6404.509277
# day 150: buy 1 unit at price 2883.979980, total balance 3520.529297
# day 151, sell 1 unit at price 2938.090088, investment 0.206001 %, total balance 6458.619385,
# day 152, sell 1 unit at price 2918.649902, investment 2.598125 %, total balance 9377.269287,
# day 155: buy 1 unit at price 2840.600098, total balance 6536.669189
# day 157: buy 1 unit at price 2888.679932, total balance 3647.989258
# day 158, sell 1 unit at price 2923.649902, investment 1.375527 %, total balance 6571.639160,
# day 159: buy 1 unit at price 2900.510010, total balance 3671.129150
# day 160: buy 1 unit at price 2924.429932, total balance 746.699219
# day 161, sell 1 unit at price 2922.949951, investment 2.899030 %, total balance 3669.649170,
# day 162: buy 1 unit at price 2847.110107, total balance 822.539062
# day 164, sell 1 unit at price 2869.159912, investment -0.675742 %, total balance 3691.698975,
# day 165: buy 1 unit at price 2887.939941, total balance 803.759033
# day 166, sell 1 unit at price 2924.580078, investment 0.829856 %, total balance 3728.339111,
# day 167: buy 1 unit at price 2926.459961, total balance 801.879150
# day 168, sell 1 unit at price 2906.270020, investment -0.620973 %, total balance 3708.149170,
# day 169: buy 1 unit at price 2937.780029, total balance 770.369141
# day 171, sell 1 unit at price 2978.709961, investment 4.622226 %, total balance 3749.079102,
# day 172: buy 1 unit at price 2978.429932, total balance 770.649170
# day 177, sell 1 unit at price 2997.959961, investment 3.809637 %, total balance 3768.609131,
# day 178, sell 1 unit at price 3005.699951, investment 2.707708 %, total balance 6774.309082,
# day 179, sell 1 unit at price 3006.729980, investment 2.347009 %, total balance 9781.039062,
# day 180, sell 1 unit at price 3006.790039, investment 0.952183 %, total balance 12787.829102,
# day 183: buy 1 unit at price 2966.600098, total balance 9821.229004
# day 185, sell 1 unit at price 2977.620117, investment 0.371470 %, total balance 12798.849121,
# day 188: buy 1 unit at price 2940.250000, total balance 9858.599121
# day 189: buy 1 unit at price 2887.610107, total balance 6970.989014
# day 192: buy 1 unit at price 2938.790039, total balance 4032.198975
# day 193: buy 1 unit at price 2893.060059, total balance 1139.138916
# day 198, sell 1 unit at price 2995.679932, investment 1.885212 %, total balance 4134.818848,
# day 199, sell 1 unit at price 2989.689941, investment 3.535098 %, total balance 7124.508789,
# day 200: buy 1 unit at price 2997.949951, total balance 4126.558838
# day 201, sell 1 unit at price 2986.199951, investment 1.613246 %, total balance 7112.758789,
# day 202, sell 1 unit at price 3006.719971, investment 3.928709 %, total balance 10119.478760,
# day 203: buy 1 unit at price 2995.989990, total balance 7123.488770
# day 204, sell 1 unit at price 3004.520020, investment 0.219152 %, total balance 10128.008789,
# day 205, sell 1 unit at price 3010.290039, investment 0.477306 %, total balance 13138.298828,

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
plt.plot(close, color='k', lw=2., alpha=0.5)
plt.plot(close, '^', markersize=10, color='g', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='r', label = 'selling signal', markevery = states_sell)
plt.title(name+'\n'+'daily Trade Recommendations')
plt.legend()
plt.xticks(rotation=45)
plt.gca().axes.get_yaxis().set_visible(False)
fig.tight_layout()
plt.savefig('images/'+ticker+name+'.png', facecolor='yellowgreen', dpi=100)
plt.show()

# %%
display_days = 30
total_days= df.shape[0]
display_from = total_days-display_days

# %%
new_buy = []
for i in(states_buy):
    if i > display_from:
        adj = i- display_from
        new_buy.append(adj)
new_buy
# Out:
# [6, 11, 12, 15, 16, 23, 26]

# %%
new_sell = []
for i in(states_sell):
    if i > display_from:
        adj = i- display_from
        new_sell.append(adj)
new_sell
# Out:
# [1, 2, 3, 8, 21, 22, 24, 25, 27, 28]

# %%
close = df['Close'][-display_days:]
fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
plt.plot(close, color='k', lw=3., alpha=0.5)
plt.plot(close, '^', markersize=12, color='g',alpha=1.0,label = 'buying signal', markevery = new_buy)
plt.plot(close, 'v', markersize=12, color='r',alpha=1.0, label = 'selling signal', markevery = new_sell)
plt.title(name+'\n'+'Last '+str(display_days)+' daily days Trade Recommendations')
plt.legend()
plt.xticks(rotation=45)
plt.gca().axes.get_yaxis().set_visible(False)
fig.tight_layout()
#plt.savefig('images/'+ticker+name+'.png', facecolor='yellowgreen', dpi=100)
plt.show()
