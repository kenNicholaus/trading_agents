# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import pandas as pd
import pandas_datareader.data as web
import pickle 
import requests
import tensorflow as tf
from sklearn.neighbors import NearestNeighbors
# Out:
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
image_path = 'D:/kenneth/agent/images/'
ticker = '^GSPC'
start=('2019-01-01')
end=('2019-12-31')
# df=web.DataReader(ticker,'yahoo',start,end)
# df.to_csv(ticker+'.csv')
df = pd.read_csv('D:/kenneth/agent/'+ticker+'.csv', index_col=0, parse_dates=True)

# %% [markdown]
# #  Agents
#
# * Turtle Trading agent
# * Moving Average agent
# * Signal Rolling agent
# * Policy Gradient agent
# * Q-learning agent
# * Evolution Strategy agent
# * Double Q-learning agent
# * Recurrent Q-learning agent
# * Double Recurrent Q-learning agent
# * Duel Q-learning agent
# * Double Duel Q-learning agent
# * Duel Recurrent Q-learning agent
# * Double Duel Recurrent Q-learning agent
# * Actor-critic agent
# * Actor-critic Duel agent
# * Actor-critic Recurrent agent
# * Actor-critic Duel Recurrent agent
# * Curiosity Q-learning agent
# * Recurrent Curiosity Q-learning agent
# * Duel Curiosity Q-learning agent
# * Neuro-evolution agent
# * Neuro-evolution with Novelty search agent
# * ABCD strategy agent
# * Deep Evolution Strategy

# %% [markdown]
# ## Neuro-evolution with Novelty search agent

# %%
name = 'Neuro-evolution with Novelty search agent'

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1

novelty_search_threshold = 6
novelty_log_maxlen = 1000
backlog_maxsize = 500
novelty_log_add_amount = 3

# %%
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.last_features = None
        self.id = id_

def relu(X):
    return np.maximum(X, 0)
    
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,
                state_size, window_size, trend, skip, initial_money):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.generation_backlog = []
        self.novel_backlog = []
        self.novel_pop = []
        
    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))
    
    def _memorize(self, q, i, limit):
        q.append(i)
        if len(q) > limit:
            q.pop()
    
    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child
    
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]
    
    def buy(self, individual):
        initial_money = self.initial_money
        starting_money = initial_money
        state = self.get_state(0)
        inventory = []
        states_sell = []
        states_buy = []
        
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(individual, state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.trend[t], invest, initial_money)
                )
            state = next_state
        
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = []
            
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)
            
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
            self.population[i].last_features = self.population[i].W2.flatten()
    
    def evaluate(self, individual, backlog, pop, k = 4):
        score = 0
        if len(backlog):
            x = np.array(backlog)
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(backlog))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)
        
        if len(pop):
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(pop))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)
        
        return score
    
    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness()
            scores = [self.evaluate(p.last_features, self.novel_backlog, self.novel_pop) for p in self.population]
            sort_fitness = np.argsort(scores)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0], 
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            
            for p in next_population:
                if p.last_features is not None:
                    self._memorize(self.novel_pop, p.last_features, backlog_maxsize)
                    if np.random.randint(0,10) < novelty_search_threshold:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)
                        
            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population
            
            if np.random.randint(0,10) < novelty_search_threshold:
                pop_sorted = sorted(self.population, key=lambda p: p.fitness, reverse=True)
                self.generation_backlog.append(pop_sorted[0])
                print('novel add fittest, score: %f, backlog size: %d'%(pop_sorted[0].fitness, 
                                                                        len(self.generation_backlog)))
                generation_backlog_temp = self.generation_backlog
                if len(self.generation_backlog) > backlog_maxsize:
                    generation_backlog_temp = random.sample(generation_backlog, backlog_maxsize)
                for p in generation_backlog_temp:
                    if p.last_features is not None:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)
                        
        return fittest_individual

# %%
population_size = 100
generations = 100
mutation_rate = 0.1
neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)

# %%
fittest_nets = neural_evolve.evolve(500)
# Out:
# novel add fittest, score: 6.504795, backlog size: 1
# novel add fittest, score: 9.797405, backlog size: 2
# epoch 5, fittest individual 61 with accuracy -76.896401
# novel add fittest, score: 0.605801, backlog size: 3
# novel add fittest, score: 3.266404, backlog size: 4
# novel add fittest, score: 8.170889, backlog size: 5
# novel add fittest, score: 8.433196, backlog size: 6
# epoch 10, fittest individual 93 with accuracy -75.542397
# novel add fittest, score: 2.873000, backlog size: 7
# novel add fittest, score: 7.999399, backlog size: 8
# epoch 15, fittest individual 40 with accuracy -78.000701
# novel add fittest, score: 0.000000, backlog size: 9
# novel add fittest, score: 8.932903, backlog size: 10
# novel add fittest, score: 0.000000, backlog size: 11
# epoch 20, fittest individual 51 with accuracy -76.425498
# novel add fittest, score: 0.000000, backlog size: 12
# novel add fittest, score: 0.000000, backlog size: 13
# novel add fittest, score: 0.000000, backlog size: 14
# epoch 25, fittest individual 73 with accuracy -75.541797
# novel add fittest, score: 0.000000, backlog size: 15
# novel add fittest, score: 5.701997, backlog size: 16
# novel add fittest, score: 8.805908, backlog size: 17
# novel add fittest, score: 0.000000, backlog size: 18
# epoch 30, fittest individual 62 with accuracy -79.796902
# novel add fittest, score: 0.000000, backlog size: 19
# novel add fittest, score: 10.428403, backlog size: 20
# novel add fittest, score: 7.218801, backlog size: 21
# novel add fittest, score: 4.468813, backlog size: 22
# novel add fittest, score: 4.468813, backlog size: 23
# epoch 35, fittest individual 59 with accuracy -74.999697
# novel add fittest, score: 7.240596, backlog size: 24
# novel add fittest, score: 0.000000, backlog size: 25
# novel add fittest, score: 0.645911, backlog size: 26
# epoch 40, fittest individual 50 with accuracy -45.485708
# novel add fittest, score: 0.000000, backlog size: 27
# novel add fittest, score: 8.064292, backlog size: 28
# epoch 45, fittest individual 76 with accuracy -78.367302
# novel add fittest, score: 0.000000, backlog size: 29
# epoch 50, fittest individual 76 with accuracy -75.458599
# novel add fittest, score: 5.599412, backlog size: 30
# epoch 55, fittest individual 50 with accuracy -51.336196
# novel add fittest, score: 0.000000, backlog size: 31
# novel add fittest, score: 11.022803, backlog size: 32
# novel add fittest, score: 11.022803, backlog size: 33
# novel add fittest, score: 11.022803, backlog size: 34
# epoch 60, fittest individual 95 with accuracy -76.187395
# novel add fittest, score: 11.022803, backlog size: 35
# novel add fittest, score: 0.000000, backlog size: 36
# novel add fittest, score: 0.000000, backlog size: 37
# epoch 65, fittest individual 43 with accuracy -75.463701
# novel add fittest, score: 0.000000, backlog size: 38
# novel add fittest, score: 0.000000, backlog size: 39
# novel add fittest, score: 0.000000, backlog size: 40
# novel add fittest, score: 0.000000, backlog size: 41
# novel add fittest, score: 5.726802, backlog size: 42
# epoch 70, fittest individual 49 with accuracy -77.282102
# novel add fittest, score: 0.000000, backlog size: 43
# novel add fittest, score: 0.000000, backlog size: 44
# novel add fittest, score: 0.000000, backlog size: 45
# epoch 75, fittest individual 49 with accuracy -76.461792
# novel add fittest, score: 0.000000, backlog size: 46
# novel add fittest, score: 0.000000, backlog size: 47
# novel add fittest, score: 0.000000, backlog size: 48
# epoch 80, fittest individual 99 with accuracy -76.225095
# novel add fittest, score: 0.000000, backlog size: 49
# novel add fittest, score: 0.000000, backlog size: 50
# novel add fittest, score: 0.000000, backlog size: 51
# epoch 85, fittest individual 0 with accuracy -75.672800
# novel add fittest, score: 0.000000, backlog size: 52
# novel add fittest, score: 0.000000, backlog size: 53
# novel add fittest, score: 0.000000, backlog size: 54
# novel add fittest, score: 0.000000, backlog size: 55
# epoch 90, fittest individual 40 with accuracy -76.908501
# novel add fittest, score: 0.000000, backlog size: 56
# novel add fittest, score: 0.000000, backlog size: 57
# novel add fittest, score: 0.000000, backlog size: 58
# epoch 95, fittest individual 57 with accuracy -76.900999
# novel add fittest, score: 0.000000, backlog size: 59
# novel add fittest, score: 0.000000, backlog size: 60
# novel add fittest, score: 0.000000, backlog size: 61
# epoch 100, fittest individual 59 with accuracy -76.042595
# novel add fittest, score: 0.000000, backlog size: 62
# novel add fittest, score: 0.000000, backlog size: 63
# novel add fittest, score: 0.000000, backlog size: 64
# novel add fittest, score: 0.000000, backlog size: 65
# epoch 105, fittest individual 68 with accuracy -75.363904
# novel add fittest, score: 0.000000, backlog size: 66
# novel add fittest, score: 0.000000, backlog size: 67
# novel add fittest, score: 0.000000, backlog size: 68
# epoch 110, fittest individual 59 with accuracy -77.181306
# novel add fittest, score: 0.000000, backlog size: 69
# epoch 115, fittest individual 40 with accuracy -78.520701
# novel add fittest, score: 0.000000, backlog size: 70
# novel add fittest, score: 0.000000, backlog size: 71
# novel add fittest, score: 0.000000, backlog size: 72
# novel add fittest, score: 0.000000, backlog size: 73
# epoch 120, fittest individual 95 with accuracy -74.867788
# novel add fittest, score: 0.000000, backlog size: 74
# novel add fittest, score: 0.000000, backlog size: 75
# epoch 125, fittest individual 0 with accuracy -82.980007
# novel add fittest, score: 0.000000, backlog size: 76
# novel add fittest, score: 0.000000, backlog size: 77
# epoch 130, fittest individual 71 with accuracy -77.942395
# novel add fittest, score: 0.000000, backlog size: 78
# novel add fittest, score: 0.000000, backlog size: 79
# novel add fittest, score: 0.000000, backlog size: 80
# epoch 135, fittest individual 76 with accuracy -78.783704
# novel add fittest, score: 0.000000, backlog size: 81
# novel add fittest, score: 0.000000, backlog size: 82
# epoch 140, fittest individual 0 with accuracy -78.239998
# novel add fittest, score: 0.000000, backlog size: 83
# novel add fittest, score: 0.000000, backlog size: 84
# novel add fittest, score: 0.000000, backlog size: 85
# epoch 145, fittest individual 0 with accuracy -77.151191
# novel add fittest, score: 0.000000, backlog size: 86
# epoch 150, fittest individual 80 with accuracy -77.781099
# novel add fittest, score: 0.000000, backlog size: 87
# novel add fittest, score: 0.000000, backlog size: 88
# novel add fittest, score: 0.000000, backlog size: 89
# epoch 155, fittest individual 86 with accuracy -77.602102
# novel add fittest, score: 0.000000, backlog size: 90
# novel add fittest, score: 0.000000, backlog size: 91
# novel add fittest, score: 0.000000, backlog size: 92
# novel add fittest, score: 0.000000, backlog size: 93
# epoch 160, fittest individual 66 with accuracy -78.146497
# novel add fittest, score: 0.000000, backlog size: 94
# novel add fittest, score: 0.000000, backlog size: 95
# novel add fittest, score: 0.000000, backlog size: 96
# novel add fittest, score: 0.000000, backlog size: 97
# epoch 165, fittest individual 73 with accuracy -76.927290
# novel add fittest, score: 0.000000, backlog size: 98
# novel add fittest, score: 0.000000, backlog size: 99
# novel add fittest, score: 0.000000, backlog size: 100
# epoch 170, fittest individual 89 with accuracy -77.776802
# novel add fittest, score: 0.000000, backlog size: 101
# novel add fittest, score: 0.000000, backlog size: 102
# novel add fittest, score: 0.000000, backlog size: 103
# novel add fittest, score: 0.000000, backlog size: 104
# novel add fittest, score: 0.000000, backlog size: 105
# epoch 175, fittest individual 0 with accuracy -81.435085
# novel add fittest, score: 0.000000, backlog size: 106
# novel add fittest, score: 0.000000, backlog size: 107
# novel add fittest, score: 0.000000, backlog size: 108
# novel add fittest, score: 0.000000, backlog size: 109
# epoch 180, fittest individual 94 with accuracy -76.891604
# novel add fittest, score: 0.000000, backlog size: 110
# epoch 185, fittest individual 0 with accuracy -76.018801
# novel add fittest, score: 0.000000, backlog size: 111
# novel add fittest, score: 0.000000, backlog size: 112
# novel add fittest, score: 0.000000, backlog size: 113
# novel add fittest, score: 0.000000, backlog size: 114
# epoch 190, fittest individual 0 with accuracy -77.707798
# novel add fittest, score: 0.000000, backlog size: 115
# novel add fittest, score: 0.000000, backlog size: 116
# novel add fittest, score: 0.000000, backlog size: 117
# novel add fittest, score: 0.000000, backlog size: 118
# epoch 195, fittest individual 87 with accuracy -80.437900
# novel add fittest, score: 0.000000, backlog size: 119
# novel add fittest, score: 0.000000, backlog size: 120
# novel add fittest, score: 0.000000, backlog size: 121
# novel add fittest, score: 0.000000, backlog size: 122
# epoch 200, fittest individual 60 with accuracy -81.033794
# novel add fittest, score: 0.000000, backlog size: 123
# epoch 205, fittest individual 87 with accuracy -77.878992
# novel add fittest, score: 0.000000, backlog size: 124
# novel add fittest, score: 0.000000, backlog size: 125
# novel add fittest, score: 0.000000, backlog size: 126
# epoch 210, fittest individual 40 with accuracy -77.486692
# novel add fittest, score: 0.000000, backlog size: 127
# epoch 215, fittest individual 85 with accuracy -79.127097
# novel add fittest, score: 0.000000, backlog size: 128
# novel add fittest, score: 0.000000, backlog size: 129
# epoch 220, fittest individual 49 with accuracy -78.269795
# novel add fittest, score: 0.000000, backlog size: 130
# novel add fittest, score: 0.000000, backlog size: 131
# epoch 225, fittest individual 95 with accuracy -84.979885
# novel add fittest, score: 0.000000, backlog size: 132
# novel add fittest, score: 0.000000, backlog size: 133
# epoch 230, fittest individual 96 with accuracy -79.816501
# novel add fittest, score: 0.000000, backlog size: 134
# epoch 235, fittest individual 64 with accuracy -74.071287
# novel add fittest, score: 0.000000, backlog size: 135
# novel add fittest, score: 0.000000, backlog size: 136
# novel add fittest, score: 0.000000, backlog size: 137
# epoch 240, fittest individual 0 with accuracy -78.548491
# novel add fittest, score: 0.000000, backlog size: 138
# novel add fittest, score: 0.000000, backlog size: 139
# novel add fittest, score: 0.000000, backlog size: 140
# novel add fittest, score: 0.000000, backlog size: 141
# epoch 245, fittest individual 84 with accuracy -82.458999
# novel add fittest, score: 0.000000, backlog size: 142
# novel add fittest, score: 0.000000, backlog size: 143
# novel add fittest, score: 0.000000, backlog size: 144
# novel add fittest, score: 0.000000, backlog size: 145
# novel add fittest, score: 0.000000, backlog size: 146
# epoch 250, fittest individual 43 with accuracy -79.775691
# novel add fittest, score: 0.000000, backlog size: 147
# novel add fittest, score: 0.000000, backlog size: 148
# novel add fittest, score: 0.000000, backlog size: 149
# epoch 255, fittest individual 85 with accuracy -89.695691
# novel add fittest, score: 0.000000, backlog size: 150
# novel add fittest, score: 0.000000, backlog size: 151
# epoch 260, fittest individual 79 with accuracy -79.718782
# novel add fittest, score: 8.815710, backlog size: 152
# novel add fittest, score: 8.815710, backlog size: 153
# novel add fittest, score: 0.000000, backlog size: 154
# epoch 265, fittest individual 48 with accuracy -83.724392
# novel add fittest, score: 0.000000, backlog size: 155
# novel add fittest, score: 7.265708, backlog size: 156
# novel add fittest, score: 0.000000, backlog size: 157
# novel add fittest, score: 6.318599, backlog size: 158
# epoch 270, fittest individual 89 with accuracy -82.136890
# novel add fittest, score: 6.318599, backlog size: 159
# novel add fittest, score: 0.000000, backlog size: 160
# novel add fittest, score: 0.000000, backlog size: 161
# epoch 275, fittest individual 58 with accuracy -83.999797
# novel add fittest, score: 0.000000, backlog size: 162
# novel add fittest, score: 0.000000, backlog size: 163
# novel add fittest, score: 0.000000, backlog size: 164
# epoch 280, fittest individual 72 with accuracy -78.277480
# novel add fittest, score: 0.000000, backlog size: 165
# novel add fittest, score: 0.000000, backlog size: 166
# epoch 285, fittest individual 63 with accuracy -83.119893
# novel add fittest, score: 0.000000, backlog size: 167
# novel add fittest, score: 0.000000, backlog size: 168
# epoch 290, fittest individual 43 with accuracy -86.530093
# novel add fittest, score: 0.000000, backlog size: 169
# novel add fittest, score: 0.000000, backlog size: 170
# novel add fittest, score: 0.000000, backlog size: 171
# epoch 295, fittest individual 47 with accuracy -80.727893
# novel add fittest, score: 0.000000, backlog size: 172
# novel add fittest, score: 0.000000, backlog size: 173
# novel add fittest, score: 0.000000, backlog size: 174
# epoch 300, fittest individual 69 with accuracy -79.558987
# novel add fittest, score: 0.000000, backlog size: 175
# novel add fittest, score: 0.000000, backlog size: 176
# epoch 305, fittest individual 54 with accuracy -80.532290
# novel add fittest, score: 0.000000, backlog size: 177
# novel add fittest, score: 8.190413, backlog size: 178
# novel add fittest, score: 0.000000, backlog size: 179
# epoch 310, fittest individual 0 with accuracy -79.825688
# novel add fittest, score: 0.000000, backlog size: 180
# novel add fittest, score: 0.000000, backlog size: 181
# novel add fittest, score: 0.000000, backlog size: 182
# epoch 315, fittest individual 68 with accuracy -78.442092
# novel add fittest, score: 0.000000, backlog size: 183
# novel add fittest, score: 0.000000, backlog size: 184
# epoch 320, fittest individual 72 with accuracy -80.419993
# novel add fittest, score: 0.000000, backlog size: 185
# novel add fittest, score: 0.000000, backlog size: 186
# novel add fittest, score: 0.000000, backlog size: 187
# epoch 325, fittest individual 89 with accuracy -77.298096
# epoch 330, fittest individual 65 with accuracy -78.947195
# novel add fittest, score: 0.000000, backlog size: 188
# novel add fittest, score: 0.000000, backlog size: 189
# novel add fittest, score: 0.000000, backlog size: 190
# epoch 335, fittest individual 0 with accuracy -81.149800
# novel add fittest, score: 0.000000, backlog size: 191
# novel add fittest, score: 0.000000, backlog size: 192
# novel add fittest, score: 0.000000, backlog size: 193
# novel add fittest, score: 0.000000, backlog size: 194
# epoch 340, fittest individual 74 with accuracy -78.720894
# novel add fittest, score: 0.000000, backlog size: 195
# novel add fittest, score: 0.000000, backlog size: 196
# novel add fittest, score: 0.000000, backlog size: 197
# epoch 345, fittest individual 85 with accuracy -79.759294
# novel add fittest, score: 0.000000, backlog size: 198
# novel add fittest, score: 0.000000, backlog size: 199
# novel add fittest, score: 0.000000, backlog size: 200
# novel add fittest, score: 0.000000, backlog size: 201
# epoch 350, fittest individual 80 with accuracy -78.931689
# novel add fittest, score: 0.000000, backlog size: 202
# novel add fittest, score: 0.000000, backlog size: 203
# novel add fittest, score: 0.000000, backlog size: 204
# novel add fittest, score: 0.000000, backlog size: 205
# epoch 355, fittest individual 60 with accuracy -75.778289
# novel add fittest, score: 0.000000, backlog size: 206
# novel add fittest, score: 5.396504, backlog size: 207
# novel add fittest, score: 0.000000, backlog size: 208
# novel add fittest, score: 0.000000, backlog size: 209
# novel add fittest, score: 0.000000, backlog size: 210
# epoch 360, fittest individual 96 with accuracy -79.110691
# novel add fittest, score: 0.000000, backlog size: 211
# novel add fittest, score: 0.000000, backlog size: 212
# novel add fittest, score: 8.390208, backlog size: 213
# novel add fittest, score: 0.000000, backlog size: 214
# epoch 365, fittest individual 42 with accuracy -85.281797
# novel add fittest, score: 0.000000, backlog size: 215
# novel add fittest, score: 0.000000, backlog size: 216
# novel add fittest, score: 0.000000, backlog size: 217
# epoch 370, fittest individual 57 with accuracy -53.062390
# novel add fittest, score: 0.000000, backlog size: 218
# novel add fittest, score: 0.000000, backlog size: 219
# novel add fittest, score: 0.000000, backlog size: 220
# epoch 375, fittest individual 68 with accuracy -75.121094
# novel add fittest, score: 0.000000, backlog size: 221
# novel add fittest, score: 0.000000, backlog size: 222
# epoch 380, fittest individual 88 with accuracy -83.696396
# novel add fittest, score: 0.000000, backlog size: 223
# novel add fittest, score: 0.000000, backlog size: 224
# epoch 385, fittest individual 0 with accuracy -81.239297
# novel add fittest, score: 0.000000, backlog size: 225
# novel add fittest, score: 0.000000, backlog size: 226
# novel add fittest, score: 0.000000, backlog size: 227
# novel add fittest, score: 0.000000, backlog size: 228
# epoch 390, fittest individual 95 with accuracy -80.320891
# novel add fittest, score: 0.000000, backlog size: 229
# novel add fittest, score: 0.000000, backlog size: 230
# novel add fittest, score: 0.000000, backlog size: 231
# novel add fittest, score: 0.000000, backlog size: 232
# epoch 395, fittest individual 0 with accuracy -77.199094
# novel add fittest, score: 0.000000, backlog size: 233
# novel add fittest, score: 0.000000, backlog size: 234
# novel add fittest, score: 0.000000, backlog size: 235
# novel add fittest, score: 0.000000, backlog size: 236
# epoch 400, fittest individual 0 with accuracy -80.929695
# novel add fittest, score: 0.000000, backlog size: 237
# novel add fittest, score: 0.000000, backlog size: 238
# novel add fittest, score: 0.000000, backlog size: 239
# novel add fittest, score: 0.000000, backlog size: 240
# epoch 405, fittest individual 59 with accuracy -84.049897
# novel add fittest, score: 0.000000, backlog size: 241
# novel add fittest, score: 0.000000, backlog size: 242
# epoch 410, fittest individual 43 with accuracy -49.245190
# novel add fittest, score: 0.000000, backlog size: 243
# novel add fittest, score: 0.000000, backlog size: 244
# novel add fittest, score: 0.000000, backlog size: 245
# novel add fittest, score: 0.000000, backlog size: 246
# epoch 415, fittest individual 0 with accuracy -80.070891
# novel add fittest, score: 0.000000, backlog size: 247
# novel add fittest, score: 0.000000, backlog size: 248
# novel add fittest, score: 0.000000, backlog size: 249
# novel add fittest, score: 0.000000, backlog size: 250
# novel add fittest, score: 0.000000, backlog size: 251
# epoch 420, fittest individual 0 with accuracy -56.105493
# novel add fittest, score: 0.000000, backlog size: 252
# novel add fittest, score: 0.000000, backlog size: 253
# novel add fittest, score: 0.000000, backlog size: 254
# novel add fittest, score: 0.000000, backlog size: 255
# epoch 425, fittest individual 0 with accuracy -82.918091
# novel add fittest, score: 0.000000, backlog size: 256
# novel add fittest, score: 0.000000, backlog size: 257
# novel add fittest, score: 0.000000, backlog size: 258
# epoch 430, fittest individual 40 with accuracy -78.416084
# novel add fittest, score: 0.000000, backlog size: 259
# novel add fittest, score: 0.000000, backlog size: 260
# novel add fittest, score: 0.000000, backlog size: 261
# novel add fittest, score: 0.000000, backlog size: 262
# epoch 435, fittest individual 90 with accuracy -49.349788
# novel add fittest, score: 0.000000, backlog size: 263
# novel add fittest, score: 0.000000, backlog size: 264
# novel add fittest, score: 0.000000, backlog size: 265
# novel add fittest, score: 0.000000, backlog size: 266
# epoch 440, fittest individual 52 with accuracy -74.766189
# novel add fittest, score: 0.000000, backlog size: 267
# novel add fittest, score: 0.000000, backlog size: 268
# novel add fittest, score: 0.000000, backlog size: 269
# novel add fittest, score: 0.000000, backlog size: 270
# epoch 445, fittest individual 55 with accuracy -73.899988
# novel add fittest, score: 0.000000, backlog size: 271
# novel add fittest, score: 0.000000, backlog size: 272
# epoch 450, fittest individual 70 with accuracy -57.404895
# novel add fittest, score: 0.000000, backlog size: 273
# novel add fittest, score: 0.000000, backlog size: 274
# novel add fittest, score: 0.000000, backlog size: 275
# novel add fittest, score: 0.000000, backlog size: 276
# epoch 455, fittest individual 0 with accuracy -51.469390
# novel add fittest, score: 0.000000, backlog size: 277
# novel add fittest, score: 7.023901, backlog size: 278
# epoch 460, fittest individual 98 with accuracy -79.004792
# novel add fittest, score: 7.023901, backlog size: 279
# novel add fittest, score: 7.023901, backlog size: 280
# novel add fittest, score: 0.000000, backlog size: 281
# novel add fittest, score: 0.000000, backlog size: 282
# epoch 465, fittest individual 0 with accuracy -81.575793
# novel add fittest, score: 0.000000, backlog size: 283
# novel add fittest, score: 0.000000, backlog size: 284
# epoch 470, fittest individual 64 with accuracy -78.646990
# novel add fittest, score: 0.000000, backlog size: 285
# novel add fittest, score: 0.000000, backlog size: 286
# novel add fittest, score: 0.000000, backlog size: 287
# epoch 475, fittest individual 0 with accuracy -82.929194
# novel add fittest, score: 0.000000, backlog size: 288
# novel add fittest, score: 0.000000, backlog size: 289
# novel add fittest, score: 0.000000, backlog size: 290
# novel add fittest, score: 0.000000, backlog size: 291
# epoch 480, fittest individual 86 with accuracy -79.891086
# novel add fittest, score: 0.000000, backlog size: 292
# novel add fittest, score: 0.000000, backlog size: 293
# novel add fittest, score: 0.000000, backlog size: 294
# epoch 485, fittest individual 0 with accuracy -83.314482
# novel add fittest, score: 0.000000, backlog size: 295
# novel add fittest, score: 0.000000, backlog size: 296
# novel add fittest, score: 0.000000, backlog size: 297
# epoch 490, fittest individual 0 with accuracy -83.184592
# novel add fittest, score: 0.000000, backlog size: 298
# novel add fittest, score: 0.000000, backlog size: 299
# novel add fittest, score: 0.000000, backlog size: 300
# novel add fittest, score: 0.000000, backlog size: 301
# epoch 495, fittest individual 70 with accuracy -78.230781
# novel add fittest, score: 0.000000, backlog size: 302
# novel add fittest, score: 0.000000, backlog size: 303
# novel add fittest, score: 0.000000, backlog size: 304
# novel add fittest, score: 0.000000, backlog size: 305
# epoch 500, fittest individual 0 with accuracy -80.887192

# %%
states_buy, states_sell, total_gains, invest = neural_evolve.buy(fittest_nets)
# Out:
# day 3: buy 1 unit at price 2549.689941, total balance 7450.310059
# day 4, sell 1 unit at price 2574.409912, investment 0.969529 %, total balance 10024.719971,
# day 5: buy 1 unit at price 2584.959961, total balance 7439.760010
# day 6: buy 1 unit at price 2596.639893, total balance 4843.120117
# day 8, sell 1 unit at price 2582.610107, investment -0.090905 %, total balance 7425.730225,
# day 9: buy 1 unit at price 2610.300049, total balance 4815.430176
# day 10, sell 1 unit at price 2616.100098, investment 0.749438 %, total balance 7431.530273,
# day 11: buy 1 unit at price 2635.959961, total balance 4795.570312
# day 12: buy 1 unit at price 2670.709961, total balance 2124.860352
# day 13: buy 1 unit at price 2632.899902, total balance -508.039551
# day 15: buy 1 unit at price 2642.330078, total balance -3150.369629
# day 16, sell 1 unit at price 2664.760010, investment 2.086349 %, total balance -485.609619,
# day 17, sell 1 unit at price 2643.850098, investment 0.299327 %, total balance 2158.240479,
# day 20: buy 1 unit at price 2704.100098, total balance -545.859619
# day 22: buy 1 unit at price 2724.870117, total balance -3270.729736
# day 23: buy 1 unit at price 2737.699951, total balance -6008.429688
# day 25: buy 1 unit at price 2706.050049, total balance -8714.479736
# day 27: buy 1 unit at price 2709.800049, total balance -11424.279785
# day 29: buy 1 unit at price 2753.030029, total balance -14177.309814
# day 30: buy 1 unit at price 2745.729980, total balance -16923.039795
# day 32: buy 1 unit at price 2779.760010, total balance -19702.799805
# day 33, sell 1 unit at price 2784.699951, investment 4.268153 %, total balance -16918.099854,
# day 37, sell 1 unit at price 2793.899902, investment 6.114931 %, total balance -14124.199951,
# day 39: buy 1 unit at price 2784.489990, total balance -16908.689941
# day 42, sell 1 unit at price 2789.649902, investment 5.575376 %, total balance -14119.040039,
# day 44: buy 1 unit at price 2748.929932, total balance -16867.969971
# day 48: buy 1 unit at price 2810.919922, total balance -19678.889893
# day 49: buy 1 unit at price 2808.479980, total balance -22487.369873
# day 50: buy 1 unit at price 2822.479980, total balance -25309.849854
# day 51: buy 1 unit at price 2832.939941, total balance -28142.789795
# day 52: buy 1 unit at price 2832.570068, total balance -30975.359863
# day 53: buy 1 unit at price 2824.229980, total balance -33799.589844
# day 54: buy 1 unit at price 2854.879883, total balance -36654.469727
# day 55: buy 1 unit at price 2800.709961, total balance -39455.179688
# day 56: buy 1 unit at price 2798.360107, total balance -42253.539795
# day 58, sell 1 unit at price 2805.370117, investment 3.745054 %, total balance -39448.169678,
# day 59, sell 1 unit at price 2815.439941, investment 3.323822 %, total balance -36632.729736,
# day 60: buy 1 unit at price 2834.399902, total balance -39467.129639
# day 61: buy 1 unit at price 2867.189941, total balance -42334.319580
# day 62, sell 1 unit at price 2867.239990, investment 4.731711 %, total balance -39467.079590,
# day 63: buy 1 unit at price 2873.399902, total balance -42340.479492
# day 65, sell 1 unit at price 2892.739990, investment 6.898983 %, total balance -39447.739502,
# day 67: buy 1 unit at price 2878.199951, total balance -42325.939453
# day 70: buy 1 unit at price 2907.409912, total balance -45233.349365
# day 71: buy 1 unit at price 2905.580078, total balance -48138.929443
# day 72: buy 1 unit at price 2907.060059, total balance -51045.989502
# day 73, sell 1 unit at price 2900.449951, investment 7.035571 %, total balance -48145.539551,
# day 74: buy 1 unit at price 2905.030029, total balance -51050.569580
# day 77: buy 1 unit at price 2927.250000, total balance -53977.819580
# day 81: buy 1 unit at price 2945.830078, total balance -56923.649658
# day 82: buy 1 unit at price 2923.729980, total balance -59847.379639
# day 84: buy 1 unit at price 2945.639893, total balance -62793.019531
# day 85, sell 1 unit at price 2932.469971, investment 6.517907 %, total balance -59860.549561,
# day 86: buy 1 unit at price 2884.050049, total balance -62744.599609
# day 87: buy 1 unit at price 2879.419922, total balance -65624.019531
# day 89, sell 1 unit at price 2881.399902, investment 4.941124 %, total balance -62742.619629,
# day 90: buy 1 unit at price 2811.870117, total balance -65554.489746
# day 93, sell 1 unit at price 2876.320068, investment 3.473683 %, total balance -62678.169678,
# day 94: buy 1 unit at price 2859.530029, total balance -65537.699707
# day 95: buy 1 unit at price 2840.229980, total balance -68377.929688
# day 97, sell 1 unit at price 2856.270020, investment 2.577852 %, total balance -65521.659668,
# day 98, sell 1 unit at price 2822.239990, investment 2.666858 %, total balance -62699.419678,
# day 100: buy 1 unit at price 2802.389893, total balance -65501.809570
# day 101: buy 1 unit at price 2783.020020, total balance -68284.829590
# day 102, sell 1 unit at price 2788.860107, investment -0.784790 %, total balance -65495.969482,
# day 104, sell 1 unit at price 2744.449951, investment -2.279882 %, total balance -62751.519531,
# day 105: buy 1 unit at price 2803.270020, total balance -65554.789551
# day 106: buy 1 unit at price 2826.149902, total balance -68380.939453
# day 107, sell 1 unit at price 2843.489990, investment 0.744381 %, total balance -65537.449463,
# day 108: buy 1 unit at price 2873.340088, total balance -68410.789551
# day 109: buy 1 unit at price 2886.729980, total balance -71297.519531
# day 110, sell 1 unit at price 2885.719971, investment 1.863083 %, total balance -68411.799561,
# day 111, sell 1 unit at price 2879.840088, investment 1.668803 %, total balance -65531.959473,
# day 112: buy 1 unit at price 2891.639893, total balance -68423.599365
# day 114: buy 1 unit at price 2889.669922, total balance -71313.269287
# day 115: buy 1 unit at price 2917.750000, total balance -74231.019287
# day 116: buy 1 unit at price 2926.459961, total balance -77157.479248
# day 117, sell 1 unit at price 2954.179932, investment 4.601252 %, total balance -74203.299316,
# day 118: buy 1 unit at price 2950.459961, total balance -77153.759277
# day 119: buy 1 unit at price 2945.350098, total balance -80099.109375
# day 120, sell 1 unit at price 2917.379883, investment 2.189234 %, total balance -77181.729492,
# day 126: buy 1 unit at price 2995.820068, total balance -80177.549561
# day 127: buy 1 unit at price 2990.409912, total balance -83167.959473
# day 128: buy 1 unit at price 2975.949951, total balance -86143.909424
# day 129: buy 1 unit at price 2979.629883, total balance -89123.539307
# day 130: buy 1 unit at price 2993.070068, total balance -92116.609375
# day 131: buy 1 unit at price 2999.909912, total balance -95116.519287
# day 132: buy 1 unit at price 3013.770020, total balance -98130.289307
# day 133: buy 1 unit at price 3014.300049, total balance -101144.589355
# day 134, sell 1 unit at price 3004.040039, investment 7.259948 %, total balance -98140.549316,
# day 138: buy 1 unit at price 2985.030029, total balance -101125.579346
# day 139: buy 1 unit at price 3005.469971, total balance -104131.049316
# day 140: buy 1 unit at price 3019.560059, total balance -107150.609375
# day 141: buy 1 unit at price 3003.669922, total balance -110154.279297
# day 143, sell 1 unit at price 3020.969971, investment 7.955011 %, total balance -107133.309326,
# day 144, sell 1 unit at price 3013.179932, investment 6.307509 %, total balance -104120.129395,
# day 146: buy 1 unit at price 2953.560059, total balance -107073.689453
# day 148: buy 1 unit at price 2844.739990, total balance -109918.429443
# day 150: buy 1 unit at price 2883.979980, total balance -112802.409424
# day 152: buy 1 unit at price 2918.649902, total balance -115721.059326
# day 153: buy 1 unit at price 2882.699951, total balance -118603.759277
# day 155, sell 1 unit at price 2840.600098, investment -0.927383 %, total balance -115763.159180,
# day 156, sell 1 unit at price 2847.600098, investment -0.897884 %, total balance -112915.559082,
# day 159: buy 1 unit at price 2900.510010, total balance -115816.069092
# day 160: buy 1 unit at price 2924.429932, total balance -118740.499023
# day 161: buy 1 unit at price 2922.949951, total balance -121663.448975
# day 162, sell 1 unit at price 2847.110107, investment -1.080184 %, total balance -118816.338867,
# day 163: buy 1 unit at price 2878.379883, total balance -121694.718750
# day 164, sell 1 unit at price 2869.159912, investment -1.315604 %, total balance -118825.558838,
# day 165, sell 1 unit at price 2887.939941, investment -0.607112 %, total balance -115937.618896,
# day 166: buy 1 unit at price 2924.580078, total balance -118862.198975
# day 167: buy 1 unit at price 2926.459961, total balance -121788.658936
# day 168: buy 1 unit at price 2906.270020, total balance -124694.928955
# day 170: buy 1 unit at price 2976.000000, total balance -127670.928955
# day 171, sell 1 unit at price 2978.709961, investment 2.464686 %, total balance -124692.218994,
# day 172, sell 1 unit at price 2978.429932, investment 2.526649 %, total balance -121713.789062,
# day 174: buy 1 unit at price 3000.929932, total balance -124714.718994
# day 175, sell 1 unit at price 3009.570068, investment 2.812198 %, total balance -121705.148926,
# day 176: buy 1 unit at price 3007.389893, total balance -124712.538818
# day 177: buy 1 unit at price 2997.959961, total balance -127710.498779
# day 179: buy 1 unit at price 3006.729980, total balance -130717.228760
# day 180, sell 1 unit at price 3006.790039, investment 2.069364 %, total balance -127710.438721,
# day 181: buy 1 unit at price 2992.070068, total balance -130702.508789
# day 182: buy 1 unit at price 2991.780029, total balance -133694.288818
# day 183: buy 1 unit at price 2966.600098, total balance -136660.888916
# day 184, sell 1 unit at price 2984.870117, investment 2.091169 %, total balance -133676.018799,
# day 186: buy 1 unit at price 2961.790039, total balance -136637.808838
# day 188: buy 1 unit at price 2940.250000, total balance -139578.058838
# day 192: buy 1 unit at price 2938.790039, total balance -142516.848877
# day 193: buy 1 unit at price 2893.060059, total balance -145409.908936
# day 194: buy 1 unit at price 2919.399902, total balance -148329.308838
# day 195, sell 1 unit at price 2938.129883, investment -0.254953 %, total balance -145391.178955,
# day 196, sell 1 unit at price 2970.270020, investment 2.989545 %, total balance -142420.908936,
# day 197: buy 1 unit at price 2966.149902, total balance -145387.058838
# day 198: buy 1 unit at price 2995.679932, total balance -148382.738770
# day 200: buy 1 unit at price 2997.949951, total balance -151380.688721
# day 201: buy 1 unit at price 2986.199951, total balance -154366.888672
# day 202, sell 1 unit at price 3006.719971, investment 4.421031 %, total balance -151360.168701,
# day 203: buy 1 unit at price 2995.989990, total balance -154356.158691
# day 204: buy 1 unit at price 3004.520020, total balance -157360.678711
# day 205: buy 1 unit at price 3010.290039, total balance -160370.968750

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
plt.plot(close, color='k', lw=2., alpha=0.5)
plt.plot(close, '^', markersize=10, color='g', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='r', label = 'selling signal', markevery = states_sell)
plt.title(name+'\n'+'daily Trade Recommendations')
plt.legend()
plt.xticks(rotation=45)
plt.gca().axes.get_yaxis().set_visible(False)
fig.tight_layout()
plt.savefig('images/'+ticker+name+'.png', facecolor='yellowgreen', dpi=100)
plt.show()

# %%
display_days = 30
total_days= df.shape[0]
display_from = total_days-display_days

# %%
new_buy = []
for i in(states_buy):
    if i > display_from:
        adj = i- display_from
        new_buy.append(adj)
new_buy
# Out:
# [2, 4, 5, 6, 9, 11, 15, 16, 17, 20, 21, 23, 24, 26, 27, 28]

# %%
new_sell = []
for i in(states_sell):
    if i > display_from:
        adj = i- display_from
        new_sell.append(adj)
new_sell
# Out:
# [3, 7, 18, 19, 25]

# %%
close = df['Close'][-display_days:]
fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
plt.plot(close, color='k', lw=3., alpha=0.5)
plt.plot(close, '^', markersize=12, color='g',alpha=1.0,label = 'buying signal', markevery = new_buy)
plt.plot(close, 'v', markersize=12, color='r',alpha=1.0, label = 'selling signal', markevery = new_sell)
plt.title(name+'\n'+'Last '+str(display_days)+' daily days Trade Recommendations')
plt.legend()
plt.xticks(rotation=45)
plt.gca().axes.get_yaxis().set_visible(False)
fig.tight_layout()
#plt.savefig('images/'+ticker+name+'.png', facecolor='yellowgreen', dpi=100)
plt.show()
