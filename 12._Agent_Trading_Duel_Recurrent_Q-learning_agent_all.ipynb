# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns
    sns.set()
    import pandas as pd
    import pandas_datareader.data as web
    import pickle 
    import requests
    import tensorflow as tf
    from collections import deque
    import random
    import os
    from datetime import date

# %%
name = 'Duel Recurrent Q-learning agent'
image_path = 'D:/kenneth/agent/images/'
path = 'D:/kenneth/trading/'
run_date=open(path+'run_date.txt').read()
start=('2019-01-01')
end=('2019-12-31')
days=30

# %%
if not os.path.exists(image_path+name):
        os.makedirs(image_path+name) 
with open('D:/kenneth/trading/sp500/sp500tickers.txt','r') as f:
    tickers=[line.rstrip('\n') for line in f]

# %%
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.X = tf.placeholder(tf.float32, (None, None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.OUTPUT_SIZE))
        cell = tf.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
        self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * self.LAYER_SIZE))
        self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
        tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
        feed_action = tf.layers.dense(tensor_action, self.OUTPUT_SIZE)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keepdims=True))
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.logits, feed_dict={self.X:states, self.hidden_layer:init_values})
        Q_new = self.sess.run(self.logits, feed_dict={self.X:new_states, self.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * np.amax(Q_new[i])
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.logits,self.last_state],
                                                feed_dict={self.X:[self.INITIAL_FEATURES],
                                                            self.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
#                 print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
#                 print(
#                     'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
#                     % (t, close[t], invest, initial_money)
#                 )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.cost, self.optimizer], 
                                        feed_dict={self.X: X, self.Y:Y,
                                                  self.hidden_layer: INIT_VAL})
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
                
            if (i+1) % checkpoint == 0:
                pass
#                 print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
#                                                                                   starting_money))

# %%
def plot_all(ticker):
    close = df['Close']
    fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
    plt.plot(close, color='k', lw=3., alpha=0.5)
    plt.plot(close, '^', markersize=10, color='g', label = 'buying signal', markevery = states_buy)
    plt.plot(close, 'v', markersize=10, color='r', label = 'selling signal', markevery = states_sell)
    plt.title(name+'\n'+'Ticker: '+ticker)
    plt.legend()
    plt.xticks(rotation=45)
    plt.gca().axes.get_yaxis().set_visible(False)
    fig.tight_layout()
    plt.savefig(image_path+name+'/'+ticker+'.png', facecolor='yellowgreen', dpi=100)
    #plt.show()
    plt.close()

# %%
def display_only(days):
    new_buy = []
    new_sell = []
    display_days = days
    total_days= df.shape[0]
    display_from = total_days-display_days
    for i in(states_buy):
        if i > display_from:
            adj = i- display_from
            new_buy.append(adj)
    for i in(states_sell):
        if i > display_from:
            adj = i- display_from
            new_sell.append(adj)
    
    return(new_buy, new_sell)

# %%
def plot_by_days(days, ticker):
    close = df['Close'][-days:]
    fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
    plt.plot(close, color='k', lw=3., alpha=0.5)
    plt.plot(close, '^', markersize=12, color='g',alpha=1.0,label = 'buying signal', markevery = new_buy)
    plt.plot(close, 'v', markersize=12, color='r',alpha=1.0, label = 'selling signal', markevery = new_sell)
    plt.title(name+'\n'+'Last '+str(days)+' Daily Trade Recommendations')
    plt.legend()
    plt.xticks(rotation=45)
    plt.gca().axes.get_yaxis().set_visible(False)
    fig.tight_layout()
    plt.savefig(image_path+name+'/'+ticker+'_'+str(days)+'.png', facecolor='yellowgreen', dpi=100)
    #plt.show()
    plt.close()

# %%
def save_signals():
    path2 = image_path+name+'/signal/'
    if not os.path.exists(path2):
        os.makedirs(path2)
        
    if  (len(states_buy)!= 0) and (len(states_sell) != 0):  
        if int(states_buy[-1])>int(states_sell[-1]):
            last_signal = 'Trading Buy'
            signal_day = str(df.index[states_buy[-1]]).split(' ')[0]
        else:
            last_signal = 'Trading Sell'
            signal_day = str(df.index[states_sell[-1]]).split(' ')[0]
        
    elif len(states_buy)== 0 and len(states_sell)>0:
        last_signal = 'Trading Sell'
        signal_day = str(df.index[states_sell[-1]]).split(' ')[0]
    elif len(states_sell)== 0 and len(states_buy)>0:
        last_signal = 'Trading Buy'
        signal_day = str(df.index[states_buy[-1]]).split(' ')[0]
    elif len(states_sell)== 0 and len(states_buy)==0:
        last_signal = 'None'
        signal_day = 'None'  
        
    with open(path2+ticker+'.txt','w') as f:
        print(
            'model_run,','signal_day,','last_signal,','total_gains,','invest,','data_start','\n',
              str(date.today()),',',signal_day,',',last_signal,',',total_gains,',',invest,',',str(start),
              file=f)

# %%
initial_money = 10000
window_size = 30
skip = 1
iterations = 10
checkpoint = 10
batch_size = 32


for ticker in tickers[157:]:
    df = pd.read_csv(path+'sp500/'+run_date+'/'+ticker+'.csv', index_col=0, parse_dates=True)
    df =df[start:end]
    print('Started ticker:', ticker)
    
    close = df.Close.values.tolist()
   
    agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
    agent.train(iterations = iterations, checkpoint = checkpoint, initial_money = initial_money)

    states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
    save_signals()
    plot_all(ticker)
#     new_buy, new_sell = display_only(days)
#     plot_by_days(days, ticker)
# Out:
# Started ticker: EBAY
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C147F8CF8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ECL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C3BF480B8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\client\session.py:1645: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Started ticker: ED
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C4CB61B00>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EFX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C4E5953C8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EIX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C4FFF72B0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C4CB610B8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EMN
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C545CA048>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EMR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C55063CC0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EOG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C56AAEF60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EQIX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C5751AF28>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EQR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C58F69B38>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ES
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C56AAE1D0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ESS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C5F61C908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ETFC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C61072CC0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ETN
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C61AEAF60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ETR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C62539240>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EVRG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C6106BEF0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EW
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C64A0FCC0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EXC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C6546BB38>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EXPD
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C66D8F978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EXPE
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C68882630>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: EXR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C6A624DA0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: F
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C6B1B9E10>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FANG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C68889E10>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FAST
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C75675C18>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FB
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C770D3C50>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FBHS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C74BF1048>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FCX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C756757F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FDX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C8164FC18>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FE
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C8308CC50>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FFIV
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C785C1438>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FIS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C8559BDA0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FISV
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C86301E10>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FITB
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C87A6A978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FLIR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C85593EB8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FLS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C89F0CC50>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FLT
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C8BC30EF0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FMC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C8C3B78D0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FOX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C8DE0AAC8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FOXA
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C8BC300F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FRC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C83B4DF28>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FRT
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C90D38BA8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FTI
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C8E87AA20>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FTNT
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C931CB080>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: FTV
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C93C2EDD8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GD
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C95640160>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GE
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014CA7860240>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GILD
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014C902B17F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GIS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014CA9D2EE80>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014CAA7A5F60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GLW
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014CAC1FAA58>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GM
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014CACC6ED68>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GOOG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014CAA7A53C8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GPC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014CAC1FA7F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GPN
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014CB0BA1E80>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: GPS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014CB1628F60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker

# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DA9BBBF60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NFLX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DAA61D978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NI
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014D66191978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NKE
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DA9BBB390>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NKTR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DAD434908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NLSN
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DAEFABCC0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NOC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB09F2F60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NOV
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB2438978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NRG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DAEFA3978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NSC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB09F2390>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NTAP
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB54F5908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NTRS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB5F7ECC0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NUE
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB79C5F60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NVDA
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB9408978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NWL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB5F74EF0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NWS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB79C5390>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: NWSA
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DBC355908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: O
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DBDDEDCC0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: OKE
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DB5F74D30>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: OMC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC02BCDA0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ORCL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC1021E10>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ORLY
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC2779978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: OXY
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC02B5EB8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PAYX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC4C3FC50>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PBCT
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC2779048>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PCAR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC7120DA0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PEG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC7B85E10>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PEP
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC95CE978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PFE
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC7117EB8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PFG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DCB92FC50>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DC95CE048>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PGR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DCDF3EDA0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PH
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DCB9254E0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PHM
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DCF43B978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PKG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DCDF36EB8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PKI
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DD28A6C50>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PLD
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DCB91D9E8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PM
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DD4CB0978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PNC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DD6722550>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PNR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DD71AEA58>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PNW
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DD8BBFD68>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PPG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DD9619240>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PPL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DD71AE7F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PRGO
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DDBB03E80>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PRU
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DDD543F60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PSA
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014DDEF86A58>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: PSX
# ...
# Started ticker: TWTR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E2D83AFD0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: TXN
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E2F5839B0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: TXT
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E2CDAA978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UA
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E27D7F0F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UAA
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E2F5834A8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UAL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E33C65D30>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UDR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E1E0985C0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UHS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E36165E10>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ULTA
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E321C79B0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UNH
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E346F0128>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UNM
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E321D7B38>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UNP
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E33C5FDD8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UPS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E386330B8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: URI
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E3CFBFD68>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: USB
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E3DA4FE48>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: UTX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E3F4939E8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: V
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E390AA710>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VAR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E3DA46DD8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VFC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E3F493780>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VIAB
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E43E48E10>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VLO
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E45890E80>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VMC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E462F6B38>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VNO
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E3FF0B710>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VRSK
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E41961978>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VRSN
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E462F6780>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VRTX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E4AE9BE10>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VTR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E3F4832B0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: VZ
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E4D369EF0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WAB
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E4EDA0908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WAT
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E4CBD35C0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WBA
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E4A40DC18>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WCG
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E51CCC2B0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WDC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E4F82A940>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WEC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E541CAEF0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WELL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E55C24908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WFC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E5371AE48>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WHR
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E5125E7F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WLTW
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E59B4B2B0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WM
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E5A5D2C50>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WMB
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E5C048EF0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WMT
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E5CAB1908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WRK
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E5A5CCE80>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WU
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E580FC7B8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WY
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E609CE2B0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: WYNN
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E41961B38>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XEC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E62DA7EF0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XEL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E638070F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLB
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E65231FD0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLE
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E5EF4F7F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLF
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E63811438>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLI
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E652314E0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLK
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E69BB89B0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLNX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E676EA780>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLP
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E6C09CFD0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLU
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E6CB22908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLV
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E6E580BA8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XLY
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E6C09C4E0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XOM
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E70A4E080>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XRAY
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E72473D30>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XRT
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E72EEDBA8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XRX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E74948908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: XYL
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E7246BF60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: YUM
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E76DF2630>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ZBH
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E7786E080>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ZION
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E792C5D30>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ZTS
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E79D3DFD0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^GSPC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E7B7411D0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^IXIC
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E7C1CCE48>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^NDX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E79D3D4E0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^SOX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E7B754780>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^TNX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014F040E8828>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^VIX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E7DF01588>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^VVIX
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014F06596DD8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^VXN
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014F07FDBE80>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^VXO
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014F08A469E8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Started ticker: ^VXV
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000014E7E6876A0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
