# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns
    sns.set()
    import pandas as pd
    import pandas_datareader.data as web
    import pickle 
    import requests
    import tensorflow as tf
    from sklearn.neighbors import NearestNeighbors
    import os
    from datetime import date

# %%
name = 'Neuro-evolution with Novelty search agent'
image_path = 'D:/kenneth/agent/images/'
path = 'D:/kenneth/trading/'
run_date=open(path+'run_date.txt').read()
start=('2019-01-01')
end=('2019-12-31')
days=30

# %%
if not os.path.exists(image_path+name):
        os.makedirs(image_path+name) 
with open('D:/kenneth/trading/sp500/sp500tickers.txt','r') as f:
    tickers=[line.rstrip('\n') for line in f]

# %%
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.last_features = None
        self.id = id_

def relu(X):
    return np.maximum(X, 0)
    
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,
                state_size, window_size, trend, skip, initial_money):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.generation_backlog = []
        self.novel_backlog = []
        self.novel_pop = []
        
    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))
    
    def _memorize(self, q, i, limit):
        q.append(i)
        if len(q) > limit:
            q.pop()
    
    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child
    
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]
    
    def buy(self, individual):
        initial_money = self.initial_money
        starting_money = initial_money
        state = self.get_state(0)
        inventory = []
        states_sell = []
        states_buy = []
        
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(individual, state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
#                 print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
#                 print(
#                     'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
#                     % (t, self.trend[t], invest, initial_money)
#                 )
            state = next_state
        
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = []
            
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)
            
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
            self.population[i].last_features = self.population[i].W2.flatten()
    
    def evaluate(self, individual, backlog, pop, k = 4):
        score = 0
        if len(backlog):
            x = np.array(backlog)
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(backlog))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)
        
        if len(pop):
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(pop))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)
        
        return score
    
    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness()
            scores = [self.evaluate(p.last_features, self.novel_backlog, self.novel_pop) for p in self.population]
            sort_fitness = np.argsort(scores)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0], 
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            
            for p in next_population:
                if p.last_features is not None:
                    self._memorize(self.novel_pop, p.last_features, backlog_maxsize)
                    if np.random.randint(0,10) < novelty_search_threshold:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)
                        
            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population
            
            if np.random.randint(0,10) < novelty_search_threshold:
                pop_sorted = sorted(self.population, key=lambda p: p.fitness, reverse=True)
                self.generation_backlog.append(pop_sorted[0])
                print('novel add fittest, score: %f, backlog size: %d'%(pop_sorted[0].fitness, 
                                                                        len(self.generation_backlog)))
                generation_backlog_temp = self.generation_backlog
                if len(self.generation_backlog) > backlog_maxsize:
                    generation_backlog_temp = random.sample(generation_backlog, backlog_maxsize)
                for p in generation_backlog_temp:
                    if p.last_features is not None:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)
                        
        return fittest_individual

# %%
def plot_all(ticker):
    close = df['Close']
    fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
    plt.plot(close, color='k', lw=3., alpha=0.5)
    plt.plot(close, '^', markersize=10, color='g', label = 'buying signal', markevery = states_buy)
    plt.plot(close, 'v', markersize=10, color='r', label = 'selling signal', markevery = states_sell)
    plt.title(name+'\n'+'Ticker: '+ticker)
    plt.legend()
    plt.xticks(rotation=45)
    plt.gca().axes.get_yaxis().set_visible(False)
    fig.tight_layout()
    plt.savefig(image_path+name+'/'+ticker+'.png', facecolor='yellowgreen', dpi=100)
    #plt.show()
    plt.close()

# %%
def display_only(days):
    new_buy = []
    new_sell = []
    display_days = days
    total_days= df.shape[0]
    display_from = total_days-display_days
    for i in(states_buy):
        if i > display_from:
            adj = i- display_from
            new_buy.append(adj)
    for i in(states_sell):
        if i > display_from:
            adj = i- display_from
            new_sell.append(adj)
    
    return(new_buy, new_sell)

# %%
def plot_by_days(days, ticker):
    close = df['Close'][-days:]
    fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
    plt.plot(close, color='k', lw=3., alpha=0.5)
    plt.plot(close, '^', markersize=12, color='g',alpha=1.0,label = 'buying signal', markevery = new_buy)
    plt.plot(close, 'v', markersize=12, color='r',alpha=1.0, label = 'selling signal', markevery = new_sell)
    plt.title(name+'\n'+'Last '+str(days)+' Daily Trade Recommendations')
    plt.legend()
    plt.xticks(rotation=45)
    plt.gca().axes.get_yaxis().set_visible(False)
    fig.tight_layout()
    plt.savefig(image_path+name+'/'+ticker+'_'+str(days)+'.png', facecolor='yellowgreen', dpi=100)
    #plt.show()
    plt.close()

# %%
def save_signals():
    path2 = image_path+name+'/signal/'
    if not os.path.exists(path2):
        os.makedirs(path2)
        
    if  (len(states_buy)!= 0) and (len(states_sell) != 0):  
        if int(states_buy[-1])>int(states_sell[-1]):
            last_signal = 'Trading Buy'
            signal_day = str(df.index[states_buy[-1]]).split(' ')[0]
        else:
            last_signal = 'Trading Sell'
            signal_day = str(df.index[states_sell[-1]]).split(' ')[0]
        
    elif len(states_buy)== 0 and len(states_sell)>0:
        last_signal = 'Trading Sell'
        signal_day = str(df.index[states_sell[-1]]).split(' ')[0]
    elif len(states_sell)== 0 and len(states_buy)>0:
        last_signal = 'Trading Buy'
        signal_day = str(df.index[states_buy[-1]]).split(' ')[0]
    elif len(states_sell)== 0 and len(states_buy)==0:
        last_signal = 'None'
        signal_day = 'None'  
        
    with open(path2+ticker+'.txt','w') as f:
        print(
            'model_run,','signal_day,','last_signal,','total_gains,','invest,','data_start','\n',
              str(date.today()),',',signal_day,',',last_signal,',',total_gains,',',invest,',',str(start),
              file=f)

# %%
initial_money = 10000
window_size = 30
skip = 1
novelty_search_threshold = 6
novelty_log_maxlen = 1000
backlog_maxsize = 500
novelty_log_add_amount = 3
population_size = 10
generations = 10
mutation_rate = 0.2

for ticker in tickers:
    df = pd.read_csv(path+'sp500/'+run_date+'/'+ticker+'.csv', index_col=0, parse_dates=True)
    df =df[start:end]
    print('Started ticker:', ticker)

    close = df.Close.values.tolist()
    neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)
    fittest_nets = neural_evolve.evolve(1)
    #fittest_nets = neural_evolve.evolve(500)
    states_buy, states_sell, total_gains, invest = neural_evolve.buy(fittest_nets)
    save_signals()
    plot_all(ticker)
#     new_buy, new_sell = display_only(days)
#     plot_by_days(days, ticker)
# Out:
# Started ticker: A
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: AAL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: AAP
# novel add fittest, score: 0.093500, backlog size: 1
# Started ticker: AAPL
# Started ticker: ABBV
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ABC
# Started ticker: ABMD
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ABT
# novel add fittest, score: 0.031600, backlog size: 1
# Started ticker: ACN
# novel add fittest, score: 0.311700, backlog size: 1
# Started ticker: ADBE
# novel add fittest, score: 0.382399, backlog size: 1
# Started ticker: ADI
# novel add fittest, score: 0.005200, backlog size: 1
# Started ticker: ADM
# Started ticker: ADP
# Started ticker: ADS
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ADSK
# novel add fittest, score: 0.199300, backlog size: 1
# Started ticker: AEE
# novel add fittest, score: 0.073900, backlog size: 1
# Started ticker: AEP
# novel add fittest, score: 0.172300, backlog size: 1
# Started ticker: AES
# novel add fittest, score: 0.017100, backlog size: 1
# Started ticker: AFL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: AGN
# novel add fittest, score: 0.216100, backlog size: 1
# Started ticker: AIG
# Started ticker: AIV
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: AIZ
# Started ticker: AJG
# novel add fittest, score: 0.357200, backlog size: 1
# Started ticker: AKAM
# novel add fittest, score: 0.147000, backlog size: 1
# Started ticker: ALB
# novel add fittest, score: 0.138900, backlog size: 1
# Started ticker: ALGN
# Started ticker: ALK
# Started ticker: ALL
# Started ticker: ALLE
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ALXN
# Started ticker: AMAT
# novel add fittest, score: 0.044200, backlog size: 1
# Started ticker: AMCR
# novel add fittest, score: 0.033800, backlog size: 1
# Started ticker: AMD
# novel add fittest, score: 0.072000, backlog size: 1
# Started ticker: AME
# novel add fittest, score: 0.064000, backlog size: 1
# Started ticker: AMG
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: AMGN
# Started ticker: AMP
# Started ticker: AMT
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: AMZN
# novel add fittest, score: 1.411396, backlog size: 1
# Started ticker: ANET
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ANSS
# novel add fittest, score: 0.351200, backlog size: 1
# Started ticker: ANTM
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: AON
# novel add fittest, score: 0.337801, backlog size: 1
# Started ticker: AOS
# Started ticker: APA
# Started ticker: APD
# Started ticker: APH
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: APTV
# novel add fittest, score: 0.716400, backlog size: 1
# Started ticker: ARE
# Started ticker: ARNC
# Started ticker: ATO
# novel add fittest, score: 0.158800, backlog size: 1
# Started ticker: ATVI
# Started ticker: AVB
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: AVGO
# novel add fittest, score: 1.374201, backlog size: 1
# Started ticker: AVY
# Started ticker: AWK
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: AXP
# novel add fittest, score: 0.075100, backlog size: 1
# Started ticker: AZO
# Started ticker: BA
# novel add fittest, score: 0.224700, backlog size: 1
# Started ticker: BAC
# novel add fittest, score: 0.051300, backlog size: 1
# Started ticker: BAX
# novel add fittest, score: 0.158300, backlog size: 1
# Started ticker: BBT
# novel add fittest, score: 0.290400, backlog size: 1
# Started ticker: BBY
# Started ticker: BDX
# Started ticker: BEN
# Started ticker: BF-B
# Started ticker: BHGE
# Started ticker: BIIB
# novel add fittest, score: 0.387900, backlog size: 1
# Started ticker: BK
# novel add fittest, score: 0.032600, backlog size: 1
# Started ticker: BKNG
# Started ticker: BLK
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: BLL
# Started ticker: BMY
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: BR
# Started ticker: BRK-B
# Started ticker: BSX
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: BWA
# Started ticker: BXP
# novel add fittest, score: 0.138300, backlog size: 1
# Started ticker: C
# Started ticker: CAG
# Started ticker: CAH
# novel add fittest, score: 0.094400, backlog size: 1
# Started ticker: CAT
# Started ticker: CB
# novel add fittest, score: 0.874100, backlog size: 1
# Started ticker: CBOE
# novel add fittest, score: 0.096500, backlog size: 1
# Started ticker: CBRE
# novel add fittest, score: 0.045600, backlog size: 1
# Started ticker: CBS
# Started ticker: CCI
# novel add fittest, score: 0.061800, backlog size: 1
# Started ticker: CCL
# Started ticker: CDNS
# Started ticker: CE
# Started ticker: CELG
# novel add fittest, score: 0.084700, backlog size: 1
# Started ticker: CERN
# novel add fittest, score: 0.138000, backlog size: 1
# Started ticker: CF
# novel add fittest, score: 0.318900, backlog size: 1
# Started ticker: CFG
# Started ticker: CHD
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: CHRW
# Started ticker: CHTR
# novel add fittest, score: 0.906601, backlog size: 1
# Started ticker: CI
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: CINF
# novel add fittest, score: 0.310000, backlog size: 1
# Started ticker: CL
# novel add fittest, score: 0.158800, backlog size: 1
# Started ticker: CLX
# Started ticker: CMA
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: CMCSA
# Started ticker: CME
# Started ticker: CMG
# Started ticker: CMI
# Started ticker: CMS
# Started ticker: CNC
# novel add fittest, score: 0.007750, backlog size: 1
# Started ticker: CNP
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: COF
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: COG
# Started ticker: COO
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: COP
# novel add fittest, score: 0.092300, backlog size: 1
# Started ticker: COST
# Started ticker: COTY
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: CPB
# Started ticker: CPRI
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: CPRT
# Started ticker: CRM
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: CSCO
# novel add fittest, score: 0.036200, backlog size: 1
# Started ticker: CSX
# Started ticker: CTAS
# novel add fittest, score: 1.127900, backlog size: 1
# Started ticker: CTL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: CTSH
# Started ticker: CTVA
# Started ticker: CTXS
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: CVS
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: CVX
# novel add fittest, score: 0.098900, backlog size: 1
# Started ticker: CXO
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: D
# Started ticker: DAL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: DD
# novel add fittest, score: 0.059096, backlog size: 1
# Started ticker: DE
# Started ticker: DFS
# novel add fittest, score: 1.438600, backlog size: 1
# Started ticker: DG
# novel add fittest, score: 2.629700, backlog size: 1
# Started ticker: DGX
# novel add fittest, score: 0.111100, backlog size: 1
# Started ticker: DHI
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: DHR
# novel add fittest, score: 0.045400, backlog size: 1
# Started ticker: DIA
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: DIS
# Started ticker: DISCA
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: DISCK
# Started ticker: DISH
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: DLR
# novel add fittest, score: 0.047001, backlog size: 1
# Started ticker: DLTR
# novel add fittest, score: 0.022900, backlog size: 1
# Started ticker: DOV
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: DOW
# Started ticker: DRE
# novel add fittest, score: 0.195700, backlog size: 1
# Started ticker: DRI
# Started ticker: DTE
# novel add fittest, score: 0.624100, backlog size: 1
# Started ticker: DUK
# Started ticker: DVA
# novel add fittest, score: 0.257600, backlog size: 1
# Started ticker: DVN
# novel add fittest, score: 0.034400, backlog size: 1
# Started ticker: DX-Y.NYB
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: DXC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: EA
# novel add fittest, score: 0.403900, backlog size: 1
# Started ticker: EBAY
# Started ticker: ECL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ED
# Started ticker: EFX
# novel add fittest, score: 0.083100, backlog size: 1
# Started ticker: EIX
# novel add fittest, score: 0.092300, backlog size: 1
# Started ticker: EL
# Started ticker: EMN
# Started ticker: EMR
# Started ticker: EOG
# Started ticker: EQIX
# Started ticker: EQR
# novel add fittest, score: 0.216100, backlog size: 1
# Started ticker: ES
# novel add fittest, score: 0.090200, backlog size: 1
# Started ticker: ESS
# novel add fittest, score: 1.073000, backlog size: 1
# Started ticker: ETFC
# novel add fittest, score: 0.023400, backlog size: 1
# Started ticker: ETN
# novel add fittest, score: 0.676900, backlog size: 1
# Started ticker: ETR
# Started ticker: EVRG
# Started ticker: EW
# novel add fittest, score: 2.198499, backlog size: 1
# Started ticker: EXC
# novel add fittest, score: 0.031000, backlog size: 1
# Started ticker: EXPD
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: EXPE
# Started ticker: EXR
# novel add fittest, score: 0.793700, backlog size: 1
# Started ticker: F
# Started ticker: FANG
# Started ticker: FAST
# Started ticker: FB
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: FBHS
# Started ticker: FCX
# Started ticker: FDX
# Started ticker: FE
# Started ticker: FFIV
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: FIS
# novel add fittest, score: 0.005800, backlog size: 1
# Started ticker: FISV
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: FITB
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: FLIR
# Started ticker: FLS
# novel add fittest, score: 0.046900, backlog size: 1
# Started ticker: FLT
# Started ticker: FMC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: FOX
# Started ticker: FOXA
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: FRC
# Started ticker: FRT
# novel add fittest, score: 0.599099, backlog size: 1
# Started ticker: FTI
# Started ticker: FTNT
# novel add fittest, score: 0.009800, backlog size: 1
# Started ticker: FTV
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: GD
# novel add fittest, score: 0.878000, backlog size: 1
# Started ticker: GE
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: GILD
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: GIS
# Started ticker: GL
# novel add fittest, score: 0.106400, backlog size: 1
# Started ticker: GLW
# novel add fittest, score: 0.003700, backlog size: 1
# Started ticker: GM
# Started ticker: GOOG
# Started ticker: GPC
# novel add fittest, score: 1.662900, backlog size: 1
# Started ticker: GPN
# novel add fittest, score: 0.665200, backlog size: 1
# Started ticker: GPS
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: GRMN
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: GS
# Started ticker: GWW
# novel add fittest, score: 2.333503, backlog size: 1
# Started ticker: HAL
# Started ticker: HAS
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HBAN
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HBI
# Started ticker: HCA
# Started ticker: HCP
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HD
# Started ticker: HES
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HFC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HIG
# novel add fittest, score: 0.015800, backlog size: 1
# Started ticker: HII
# Started ticker: HLT
# novel add fittest, score: 0.163400, backlog size: 1
# Started ticker: HOG
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HOLX
# Started ticker: HON
# Started ticker: HP
# novel add fittest, score: 0.042100, backlog size: 1
# Started ticker: HPE
# novel add fittest, score: 0.048700, backlog size: 1
# Started ticker: HPQ
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HRB
# Started ticker: HRL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HSIC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HST
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: HSY
# Started ticker: HUM
# Started ticker: IBM
# novel add fittest, score: 0.148001, backlog size: 1
# Started ticker: ICE
# novel add fittest, score: 0.033200, backlog size: 1
# Started ticker: IDXX
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: IEX
# Started ticker: IFF
# novel add fittest, score: 0.320700, backlog size: 1
# Started ticker: ILMN
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: INCY
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: INFO
# Started ticker: INTC
# novel add fittest, score: 0.021700, backlog size: 1
# Started ticker: INTU
# Started ticker: IP
# novel add fittest, score: 0.081300, backlog size: 1
# Started ticker: IPG
# Started ticker: IPGP
# novel add fittest, score: 0.003500, backlog size: 1
# Started ticker: IQV
# Started ticker: IR
# Started ticker: IRM
# Started ticker: ISRG
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: IT
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ITW
# novel add fittest, score: 0.074900, backlog size: 1
# Started ticker: IVZ
# novel add fittest, score: 0.004200, backlog size: 1
# Started ticker: JBHT
# Started ticker: JCI
# Started ticker: JEC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: JEF
# novel add fittest, score: 0.106746, backlog size: 1
# Started ticker: JKHY
# Started ticker: JNJ
# Started ticker: JNPR
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: JPM
# Started ticker: JWN
# Started ticker: K
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: KEY
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: KEYS
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: KHC
# Started ticker: KIM
# novel add fittest, score: 0.030100, backlog size: 1
# Started ticker: KLAC
# Started ticker: KMB
# Started ticker: KMI
# novel add fittest, score: 0.005700, backlog size: 1
# Started ticker: KMX
# Started ticker: KO
# Started ticker: KR
# Started ticker: KSS
# novel add fittest, score: 0.089000, backlog size: 1
# Started ticker: KSU
# Started ticker: L
# novel add fittest, score: 0.008600, backlog size: 1
# Started ticker: LB
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: LDOS
# Started ticker: LEG
# novel add fittest, score: 0.020700, backlog size: 1
# Started ticker: LEN
# Started ticker: LH
# Started ticker: LHX
# novel add fittest, score: 0.151700, backlog size: 1
# Started ticker: LIN
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: LKQ
# Started ticker: LLY
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: LMT
# Started ticker: LNC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: LNT
# Started ticker: LOW
# Started ticker: LRCX
# novel add fittest, score: 0.165701, backlog size: 1
# Started ticker: LUV
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: LW
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: LYB
# Started ticker: M
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MA
# Started ticker: MAA
# Started ticker: MAC
# Started ticker: MAR
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MAS
# Started ticker: MCD
# novel add fittest, score: 0.053300, backlog size: 1
# Started ticker: MCHP
# Started ticker: MCK
# novel add fittest, score: 0.333400, backlog size: 1
# Started ticker: MCO
# novel add fittest, score: 0.038700, backlog size: 1
# Started ticker: MDLZ
# novel add fittest, score: 0.131400, backlog size: 1
# Started ticker: MDT
# Started ticker: MET
# Started ticker: MGM
# novel add fittest, score: 0.012900, backlog size: 1
# Started ticker: MHK
# Started ticker: MKC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MKTX
# novel add fittest, score: 3.430300, backlog size: 1
# Started ticker: MLM
# Started ticker: MMC
# novel add fittest, score: 0.023100, backlog size: 1
# Started ticker: MMM
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MNST
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MO
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MOS
# Started ticker: MPC
# novel add fittest, score: 0.222300, backlog size: 1
# Started ticker: MRK
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MRO
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MS
# Started ticker: MSCI
# novel add fittest, score: 0.052100, backlog size: 1
# Started ticker: MSFT
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MSI
# Started ticker: MTB
# Started ticker: MTD
# Started ticker: MU
# novel add fittest, score: 0.628400, backlog size: 1
# Started ticker: MXIM
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: MYL
# Started ticker: NBL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: NCLH
# novel add fittest, score: 0.006500, backlog size: 1
# Started ticker: NDAQ
# novel add fittest, score: 0.051500, backlog size: 1
# Started ticker: NEE
# novel add fittest, score: 0.256200, backlog size: 1
# Started ticker: NEM
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: NFLX
# Started ticker: NI
# Started ticker: NKE
# novel add fittest, score: 0.139800, backlog size: 1
# Started ticker: NKTR
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: NLSN
# Started ticker: NOC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: NOV
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: NRG
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: NSC
# novel add fittest, score: 0.273500, backlog size: 1
# Started ticker: NTAP
# Started ticker: NTRS
# Started ticker: NUE
# Started ticker: NVDA
# novel add fittest, score: 0.104000, backlog size: 1
# Started ticker: NWL
# Started ticker: NWS
# Started ticker: NWSA
# novel add fittest, score: 0.011600, backlog size: 1
# Started ticker: O
# novel add fittest, score: 0.156500, backlog size: 1
# Started ticker: OKE
# novel add fittest, score: 0.008000, backlog size: 1
# Started ticker: OMC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ORCL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ORLY
# Started ticker: OXY
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: PAYX
# Started ticker: PBCT
# novel add fittest, score: 0.093800, backlog size: 1
# Started ticker: PCAR
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: PEG
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: PEP
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: PFE
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: PFG
# Started ticker: PG
# novel add fittest, score: 0.217800, backlog size: 1
# Started ticker: PGR
# Started ticker: PH
# Started ticker: PHM
# novel add fittest, score: 0.142300, backlog size: 1
# Started ticker: PKG
# novel add fittest, score: 0.632600, backlog size: 1
# Started ticker: PKI
# Started ticker: PLD
# Started ticker: PM
# Started ticker: PNC
# Started ticker: PNR
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: PNW
# novel add fittest, score: 0.044100, backlog size: 1
# Started ticker: PPG
# novel add fittest, score: 0.272900, backlog size: 1
# Started ticker: PPL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: PRGO
# Started ticker: PRU
# Started ticker: PSA
# Started ticker: PSX
# novel add fittest, score: 0.439200, backlog size: 1
# Started ticker: PVH
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: PWR
# novel add fittest, score: 0.145800, backlog size: 1
# Started ticker: PXD
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: PYPL
# novel add fittest, score: 0.318500, backlog size: 1
# Started ticker: QCOM
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: QRVO
# novel add fittest, score: 0.029200, backlog size: 1
# Started ticker: RCL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: RE
# novel add fittest, score: 0.542200, backlog size: 1
# Started ticker: REG
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: REGN
# Started ticker: RF
# Started ticker: RHI
# novel add fittest, score: 0.297300, backlog size: 1
# Started ticker: RJF
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: RL
# novel add fittest, score: 0.144500, backlog size: 1
# Started ticker: RMD
# novel add fittest, score: 0.867199, backlog size: 1
# Started ticker: ROK
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ROL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ROP
# novel add fittest, score: 1.239901, backlog size: 1
# Started ticker: ROST
# Started ticker: RSG
# Started ticker: RTN
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: SBAC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: SBUX
# Started ticker: SCHW
# Started ticker: SEE
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: SHW
# Started ticker: SIVB
# novel add fittest, score: 0.697800, backlog size: 1
# Started ticker: SJM
# Started ticker: SLB
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: SLG
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: SNA
# Started ticker: SNPS
# novel add fittest, score: 1.389800, backlog size: 1
# Started ticker: SO
# Started ticker: SPG
# novel add fittest, score: 0.055000, backlog size: 1
# Started ticker: SPGI
# Started ticker: SPY
# Started ticker: SRE
# novel add fittest, score: 0.022200, backlog size: 1
# Started ticker: STI
# novel add fittest, score: 0.056400, backlog size: 1
# Started ticker: STT
# novel add fittest, score: 0.522800, backlog size: 1
# Started ticker: STX
# Started ticker: STZ
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: SWK
# novel add fittest, score: 0.367100, backlog size: 1
# Started ticker: SWKS
# Started ticker: SYF
# Started ticker: SYK
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: SYMC
# Started ticker: SYY
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: T
# novel add fittest, score: 0.036700, backlog size: 1
# Started ticker: TAP
# Started ticker: TDG
# novel add fittest, score: 1.372000, backlog size: 1
# Started ticker: TEL
# Started ticker: TFX
# Started ticker: TGT
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: TIF
# Started ticker: TJX
# Started ticker: TMO
# novel add fittest, score: 0.684700, backlog size: 1
# Started ticker: TMUS
# Started ticker: TPR
# novel add fittest, score: 0.025200, backlog size: 1
# Started ticker: TRIP
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: TROW
# Started ticker: TRV
# Started ticker: TSCO
# Started ticker: TSN
# Started ticker: TSS
# novel add fittest, score: 0.466600, backlog size: 1
# Started ticker: TTWO
# novel add fittest, score: 0.231400, backlog size: 1
# Started ticker: TWTR
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: TXN
# Started ticker: TXT
# Started ticker: UA
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: UAA
# Started ticker: UAL
# Started ticker: UDR
# novel add fittest, score: 0.073600, backlog size: 1
# Started ticker: UHS
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ULTA
# novel add fittest, score: 0.318400, backlog size: 1
# Started ticker: UNH
# novel add fittest, score: 0.860100, backlog size: 1
# Started ticker: UNM
# novel add fittest, score: 0.006500, backlog size: 1
# Started ticker: UNP
# Started ticker: UPS
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: URI
# Started ticker: USB
# Started ticker: UTX
# novel add fittest, score: 0.218600, backlog size: 1
# Started ticker: V
# Started ticker: VAR
# Started ticker: VFC
# novel add fittest, score: 0.114816, backlog size: 1
# Started ticker: VIAB
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: VLO
# novel add fittest, score: 0.124600, backlog size: 1
# Started ticker: VMC
# novel add fittest, score: 0.148800, backlog size: 1
# Started ticker: VNO
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: VRSK
# novel add fittest, score: 0.226300, backlog size: 1
# Started ticker: VRSN
# Started ticker: VRTX
# novel add fittest, score: 0.632799, backlog size: 1
# Started ticker: VTR
# Started ticker: VZ
# Started ticker: WAB
# novel add fittest, score: 0.006800, backlog size: 1
# Started ticker: WAT
# Started ticker: WBA
# novel add fittest, score: 0.003700, backlog size: 1
# Started ticker: WCG
# Started ticker: WDC
# Started ticker: WEC
# novel add fittest, score: 0.025000, backlog size: 1
# Started ticker: WELL
# Started ticker: WFC
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: WHR
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: WLTW
# novel add fittest, score: 0.090900, backlog size: 1
# Started ticker: WM
# Started ticker: WMB
# novel add fittest, score: 0.033300, backlog size: 1
# Started ticker: WMT
# novel add fittest, score: 0.479600, backlog size: 1
# Started ticker: WRK
# novel add fittest, score: 0.347800, backlog size: 1
# Started ticker: WU
# novel add fittest, score: 0.025200, backlog size: 1
# Started ticker: WY
# Started ticker: WYNN
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: XEC
# Started ticker: XEL
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: XLB
# Started ticker: XLE
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: XLF
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: XLI
# Started ticker: XLK
# Started ticker: XLNX
# novel add fittest, score: 0.354300, backlog size: 1
# Started ticker: XLP
# Started ticker: XLU
# novel add fittest, score: 0.033200, backlog size: 1
# Started ticker: XLV
# novel add fittest, score: 0.006500, backlog size: 1
# Started ticker: XLY
# novel add fittest, score: 0.083700, backlog size: 1
# Started ticker: XOM
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: XRAY
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: XRT
# Started ticker: XRX
# Started ticker: XYL
# novel add fittest, score: 0.051800, backlog size: 1
# Started ticker: YUM
# novel add fittest, score: 0.011600, backlog size: 1
# Started ticker: ZBH
# Started ticker: ZION
# novel add fittest, score: 0.099900, backlog size: 1
# Started ticker: ZTS
# novel add fittest, score: 0.103900, backlog size: 1
# Started ticker: ^GSPC
# novel add fittest, score: 0.775403, backlog size: 1
# Started ticker: ^IXIC
# novel add fittest, score: 16.527910, backlog size: 1
# Started ticker: ^NDX
# Started ticker: ^SOX
# novel add fittest, score: 8.763601, backlog size: 1
# Started ticker: ^TNX
# Started ticker: ^VIX
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ^VVIX
# Started ticker: ^VXN
# novel add fittest, score: 0.000000, backlog size: 1
# Started ticker: ^VXO
# novel add fittest, score: 0.071900, backlog size: 1
# Started ticker: ^VXV
# novel add fittest, score: 0.067200, backlog size: 1
