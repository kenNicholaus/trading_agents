# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import pandas as pd
import pandas_datareader.data as web
import pickle 
import requests
import tensorflow as tf
# Out:
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
image_path = 'D:/kenneth/agent/images/'
ticker = '^GSPC'
start=('2019-01-01')
end=('2019-12-31')
df=web.DataReader(ticker,'yahoo',start,end)
df.to_csv(ticker+'.csv')
#df = pd.read_csv('D:/kenneth/agent/'+ticker+'.csv', index_col=0, parse_dates=True)

# %% [markdown]
# #  Agents
#
# * Turtle Trading agent
# * Moving Average agent
# * Signal Rolling agent
# * Policy Gradient agent
# * Q-learning agent
# * Evolution Strategy agent
# * Double Q-learning agent
# * Recurrent Q-learning agent
# * Double Recurrent Q-learning agent
# * Duel Q-learning agent
# * Double Duel Q-learning agent
# * Duel Recurrent Q-learning agent
# * Double Duel Recurrent Q-learning agent
# * Actor-critic agent
# * Actor-critic Duel agent
# * Actor-critic Recurrent agent
# * Actor-critic Duel Recurrent agent
# * Curiosity Q-learning agent
# * Recurrent Curiosity Q-learning agent
# * Duel Curiosity Q-learning agent
# * Neuro-evolution agent
# * Neuro-evolution with Novelty search agent
# * ABCD strategy agent
# * Deep Evolution Strategy

# %% [markdown]
# ## Duel Q-learning agent

# %%
from collections import deque
import random

name = 'Duel Q-learning agent'

class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 512, activation = tf.nn.relu)
        tensor_action, tensor_validation = tf.split(feed,2,1)
        feed_action = tf.layers.dense(tensor_action, self.action_size)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 10
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 100, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b6580833e06e>:31: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# epoch: 10, total rewards: 1176.149902.3, cost: 0.448690, total money: 5212.050049
# epoch: 20, total rewards: 1179.969727.3, cost: 0.134266, total money: 2336.949707
# epoch: 30, total rewards: 1118.310059.3, cost: 0.079723, total money: 2275.290039
# epoch: 40, total rewards: 1330.930176.3, cost: 0.063602, total money: 2519.710205
# epoch: 50, total rewards: 1188.010254.3, cost: 0.048308, total money: 2344.990234
# epoch: 60, total rewards: 1296.940186.3, cost: 0.038555, total money: 2453.920166
# epoch: 70, total rewards: 1276.710205.3, cost: 0.033228, total money: 2433.690186
# epoch: 80, total rewards: 1247.450439.3, cost: 0.026209, total money: 2404.430420
# epoch: 90, total rewards: 1160.070068.3, cost: 0.241429, total money: 2317.050049
# epoch: 100, total rewards: 1090.380127.3, cost: 0.045071, total money: 2229.790283

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 4: buy 1 unit at price 2574.409912, total balance 7425.590088
# day 7, sell 1 unit at price 2596.260010, investment 0.848742 %, total balance 10021.850098,
# day 8: buy 1 unit at price 2582.610107, total balance 7439.239990
# day 9: buy 1 unit at price 2610.300049, total balance 4828.939941
# day 10: buy 1 unit at price 2616.100098, total balance 2212.839844
# day 15, sell 1 unit at price 2642.330078, investment 2.312388 %, total balance 4855.169922,
# day 16: buy 1 unit at price 2664.760010, total balance 2190.409912
# day 18, sell 1 unit at price 2640.000000, investment 1.137798 %, total balance 4830.409912,
# day 21, sell 1 unit at price 2706.530029, investment 3.456669 %, total balance 7536.939941,
# day 22: buy 1 unit at price 2724.870117, total balance 4812.069824
# day 24: buy 1 unit at price 2731.610107, total balance 2080.459717
# day 25, sell 1 unit at price 2706.050049, investment 1.549484 %, total balance 4786.509766,
# day 26: buy 1 unit at price 2707.879883, total balance 2078.629883
# day 31, sell 1 unit at price 2775.600098, investment 1.861739 %, total balance 4854.229980,
# day 33, sell 1 unit at price 2784.699951, investment 1.943537 %, total balance 7638.929932,
# day 34: buy 1 unit at price 2774.879883, total balance 4864.050049
# day 35: buy 1 unit at price 2792.669922, total balance 2071.380127
# day 38, sell 1 unit at price 2792.379883, investment 3.120522 %, total balance 4863.760010,
# day 40, sell 1 unit at price 2803.689941, investment 1.038245 %, total balance 7667.449951,
# day 42, sell 1 unit at price 2789.649902, investment -0.108141 %, total balance 10457.099854,
# day 44: buy 1 unit at price 2748.929932, total balance 7708.169922
# day 46, sell 1 unit at price 2783.300049, investment 1.250309 %, total balance 10491.469971,
# day 47: buy 1 unit at price 2791.520020, total balance 7699.949951
# day 50: buy 1 unit at price 2822.479980, total balance 4877.469971
# day 51, sell 1 unit at price 2832.939941, investment 1.483777 %, total balance 7710.409912,
# day 52: buy 1 unit at price 2832.570068, total balance 4877.839844
# day 53: buy 1 unit at price 2824.229980, total balance 2053.609863
# day 54, sell 1 unit at price 2854.879883, investment 1.147923 %, total balance 4908.489746,
# day 55: buy 1 unit at price 2800.709961, total balance 2107.779785
# day 59, sell 1 unit at price 2815.439941, investment -0.604756 %, total balance 4923.219727,
# day 60: buy 1 unit at price 2834.399902, total balance 2088.819824
# day 63, sell 1 unit at price 2873.399902, investment 1.741003 %, total balance 4962.219727,
# day 64: buy 1 unit at price 2879.389893, total balance 2082.829834
# day 65, sell 1 unit at price 2892.739990, investment 3.285954 %, total balance 4975.569824,
# day 67: buy 1 unit at price 2878.199951, total balance 2097.369873
# day 68, sell 1 unit at price 2888.209961, investment 1.898464 %, total balance 4985.579834,
# day 72: buy 1 unit at price 2907.060059, total balance 2078.519775
# day 76, sell 1 unit at price 2933.679932, investment 1.885470 %, total balance 5012.199707,
# day 77: buy 1 unit at price 2927.250000, total balance 2084.949707
# day 79, sell 1 unit at price 2939.879883, investment 2.143004 %, total balance 5024.829590,
# day 81, sell 1 unit at price 2945.830078, investment 1.333650 %, total balance 7970.659668,
# day 82: buy 1 unit at price 2923.729980, total balance 5046.929688
# day 84, sell 1 unit at price 2945.639893, investment 0.628231 %, total balance 7992.569580,
# day 86, sell 1 unit at price 2884.050049, investment -1.357168 %, total balance 10876.619629,
# day 93: buy 1 unit at price 2876.320068, total balance 8000.299561
# day 95: buy 1 unit at price 2840.229980, total balance 5160.069580
# day 97, sell 1 unit at price 2856.270020, investment -0.697073 %, total balance 8016.339600,
# day 98, sell 1 unit at price 2822.239990, investment -0.633399 %, total balance 10838.579590,
# day 99: buy 1 unit at price 2826.060059, total balance 8012.519531
# day 101: buy 1 unit at price 2783.020020, total balance 5229.499512
# day 104, sell 1 unit at price 2744.449951, investment -2.887770 %, total balance 7973.949463,
# day 106: buy 1 unit at price 2826.149902, total balance 5147.799561
# day 107: buy 1 unit at price 2843.489990, total balance 2304.309570
# day 115, sell 1 unit at price 2917.750000, investment 4.841143 %, total balance 5222.059570,
# day 117, sell 1 unit at price 2954.179932, investment 4.530192 %, total balance 8176.239502,
# day 119: buy 1 unit at price 2945.350098, total balance 5230.889404
# day 120: buy 1 unit at price 2917.379883, total balance 2313.509521
# day 126, sell 1 unit at price 2995.820068, investment 5.357152 %, total balance 5309.329590,
# day 128, sell 1 unit at price 2975.949951, investment 1.038921 %, total balance 8285.279541,
# day 129: buy 1 unit at price 2979.629883, total balance 5305.649658
# day 130, sell 1 unit at price 2993.070068, investment 2.594458 %, total balance 8298.719727,
# day 131, sell 1 unit at price 2999.909912, investment 0.680622 %, total balance 11298.629639,
# day 136: buy 1 unit at price 2995.110107, total balance 8303.519531
# day 138: buy 1 unit at price 2985.030029, total balance 5318.489502
# day 141: buy 1 unit at price 3003.669922, total balance 2314.819580
# day 145, sell 1 unit at price 2980.379883, investment -0.491809 %, total balance 5295.199463,
# day 146, sell 1 unit at price 2953.560059, investment -1.054260 %, total balance 8248.759521,
# day 149, sell 1 unit at price 2881.770020, investment -4.058365 %, total balance 11130.529541,
# day 153: buy 1 unit at price 2882.699951, total balance 8247.829590
# day 155, sell 1 unit at price 2840.600098, investment -1.460431 %, total balance 11088.429688,
# day 158: buy 1 unit at price 2923.649902, total balance 8164.779785
# day 160: buy 1 unit at price 2924.429932, total balance 5240.349854
# day 162, sell 1 unit at price 2847.110107, investment -2.617953 %, total balance 8087.459961,
# day 163, sell 1 unit at price 2878.379883, investment -1.574668 %, total balance 10965.839844,
# day 164: buy 1 unit at price 2869.159912, total balance 8096.679932
# day 167: buy 1 unit at price 2926.459961, total balance 5170.219971
# day 168: buy 1 unit at price 2906.270020, total balance 2263.949951
# day 172, sell 1 unit at price 2978.429932, investment 3.808433 %, total balance 5242.379883,
# day 176: buy 1 unit at price 3007.389893, total balance 2234.989990
# day 186, sell 1 unit at price 2961.790039, investment 1.207263 %, total balance 5196.780029,
# day 189, sell 1 unit at price 2887.610107, investment -0.642057 %, total balance 8084.390137,
# day 190: buy 1 unit at price 2910.629883, total balance 5173.760254
# day 191: buy 1 unit at price 2952.010010, total balance 2221.750244
# day 192, sell 1 unit at price 2938.790039, investment -2.281043 %, total balance 5160.540283,
# day 193: buy 1 unit at price 2893.060059, total balance 2267.480225
# day 196, sell 1 unit at price 2970.270020, investment 2.049046 %, total balance 5237.750244,
# day 200: buy 1 unit at price 2997.949951, total balance 2239.800293

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
plt.plot(close, color='k', lw=3., alpha=0.5)
plt.plot(close, '^', markersize=10, color='g', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='r', label = 'selling signal', markevery = states_sell)
plt.title(name+'\n'+'daily Trade Recommendations')
plt.legend()
plt.xticks(rotation=45)
plt.gca().axes.get_yaxis().set_visible(False)
fig.tight_layout()
plt.savefig('images/'+ticker+name+'.png', facecolor='yellowgreen', dpi=100)
plt.show()

# %%
display_days = 30
total_days= df.shape[0]
display_from = total_days-display_days

# %%
new_buy = []
for i in(states_buy):
    if i > display_from:
        adj = i- display_from
        new_buy.append(adj)
new_buy
# Out:
# [13, 14, 16, 23]

# %%
new_sell = []
for i in(states_sell):
    if i > display_from:
        adj = i- display_from
        new_sell.append(adj)
new_sell
# Out:
# [9, 12, 15, 19]

# %%
close = df['Close'][-display_days:]
fig = plt.figure(figsize = (15,5), facecolor='yellowgreen', dpi=100)
plt.plot(close, color='k', lw=3., alpha=0.5)
plt.plot(close, '^', markersize=12, color='g',alpha=1.0,label = 'buying signal', markevery = new_buy)
plt.plot(close, 'v', markersize=12, color='r',alpha=1.0, label = 'selling signal', markevery = new_sell)
plt.title(name+'\n'+'Last '+str(display_days)+' daily days Trade Recommendations')
plt.legend()
plt.xticks(rotation=45)
plt.gca().axes.get_yaxis().set_visible(False)
fig.tight_layout()
#plt.savefig('images/'+ticker+name+'.png', facecolor='yellowgreen', dpi=100)
plt.show()
