# %%
# %run 1.0_Agent_Trading_Turtle_Trading_Agent.ipynb
# %run 2.0_Agent_Trading_moving_average_agent.ipynb
# %run 3.0_Agent_Trading_Signal_Rolling_agent.ipynb
# %run 4.0_Agent_Trading_Policy_Gradient_agent.ipynb
# %run 5.0_Agent_Trading_Q-learning_agent.ipynb
# %run 6.0_Agent_Trading_Evolution_Strategy_agent.ipynb
# %run 7.0_Agent_Trading_Double_Q-learning_agent.ipynb
# %run 8.0_Agent_Trading_Recurrent_Q-learning_agent.ipynb
# %run 9.0_Agent_Trading_Double_Recurrent_Q-learning_agent.ipynb
# %run 10._Agent_Trading_Duel_Q-learning_agent.ipynb
# %run 11._Agent_Trading_Double_Duel_Q-learning_agent.ipynb
# %run 12._Agent_Trading_Duel_Recurrent_Q-learning_agent.ipynb
# %run 13._Agent_Trading_Double_Duel_Recurrent_Q-learning_agent.ipynb
# %run 14._Agent_Trading_Actor-critic_agent.ipynb
# %run 15._Agent_Trading_Actor-critic_Duel_agent.ipynb
# %run 17._Agent_Trading_Actor-critic_Duel_Recurrent_agent.ipynb
# %run 16._Agent_Trading_Actor-critic_Recurrent_agent.ipynb
# %run 18._Agent_Trading_Curiosity_Q-learning_agent.ipynb
# %run 19._Agent_Trading_Recurrent_Curiosity_Q-learning_agent.ipynb
# %run 20._Agent_Trading_Duel Curiosity_Q-learning_agent.ipynb
# %run 22._Agent_Trading_Neuro-evolution_with_Novelty_search_agent.ipynb
# %run 21._Agent_Trading_Neuro-evolution_agent.ipynb
# %run 23._Agent_Trading_ABCD_strategy_agent.ipynb
# %run 24._Agent_Trading_Deep_Evolution_Strategy.ipynb
# Out:
# day 2430: cannot sell anything, inventory 0
# day 2432: cannot sell anything, inventory 0
# day 2433: cannot sell anything, inventory 0
# day 2434: cannot sell anything, inventory 0
# day 2435: cannot sell anything, inventory 0
# day 2438: cannot sell anything, inventory 0
# day 2442: cannot sell anything, inventory 0
# day 2455: cannot sell anything, inventory 0
# day 2466: cannot sell anything, inventory 0
# day 2539: cannot sell anything, inventory 0
# day 2541: cannot sell anything, inventory 0
# day 2542: cannot sell anything, inventory 0
# day 2544: cannot sell anything, inventory 0
# day 2546: cannot sell anything, inventory 0
# day 2551: cannot sell anything, inventory 0
# day 2552: cannot sell anything, inventory 0
# day 2553: cannot sell anything, inventory 0
# day 2556: cannot sell anything, inventory 0
# day 2660: cannot sell anything, inventory 0
# day 2663: cannot sell anything, inventory 0
# day 2664: cannot sell anything, inventory 0
# ...
